# %% [markdown]
# # 火灾检测流程演示
#
# 本 Notebook 演示完整的火灾检测流程：
# 1. 从视频/RTSP流中读取帧
# 2. 使用 YOLO 分割模型检测火焰/烟雾
# 3. 使用时序分类模型判断动态/静态
# 4. 输出检测结果

# %% [markdown]
# ## 1. 环境设置与导入

# %%
import sys
import cv2
import torch
import numpy as np
from pathlib import Path
from typing import List, Optional, Tuple
from dataclasses import dataclass
from enum import Enum
import time
import matplotlib.pyplot as plt

# 添加项目根目录到路径
project_root = Path('.').resolve()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from convlstm import create_model, heatmap_to_prob
from segment import VideoSegmentProcessor, ROIMode

print(f"PyTorch 版本: {torch.__version__}")
print(f"CUDA 可用: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA 设备: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch 版本: 2.8.0+cu129
# CUDA 可用: True
# CUDA 设备: NVIDIA GeForce RTX 4070 Ti SUPER

# %% [markdown]
# ## 2. 定义检测结果类型

# %%
class DetectionResult(Enum):
    """检测结果类型"""
    NO_DETECTION = "no_detection"          # 未检测到火焰/烟雾
    FIRE_DETECTED = "fire_detected"        # 检测到火灾（动态）
    STATIC_SUSPECTED = "static_suspected"  # 静态疑似（可能是图片或反光）


@dataclass
class FireDetectionOutput:
    """火灾检测输出"""
    result: DetectionResult
    confidence: float
    message: str
    frame_count: int
    detections: List[dict]
    heatmap: Optional[np.ndarray] = None

# %% [markdown]
# ## 3. 火灾检测器类

# %%
class FireDetector:
    """火灾检测器"""

    def __init__(
        self,
        segment_model_path: str,
        temporal_model_path: str,
        seq_length: int = 10,
        frame_size: Tuple[int, int] = (640, 640),
        segment_conf: float = 0.5,
        temporal_threshold: float = 0.5,
        device: str = 'auto'
    ):
        """
        初始化火灾检测器

        Args:
            segment_model_path: YOLO 分割模型路径
            temporal_model_path: 时序分类模型路径
            seq_length: 每次处理的帧数
            frame_size: 帧尺寸 (H, W)
            segment_conf: 分割模型置信度阈值
            temporal_threshold: 时序分类阈值
            device: 推理设备
        """
        self.seq_length = seq_length
        self.frame_size = frame_size
        self.temporal_threshold = temporal_threshold

        # 设置设备
        if device == 'auto':
            self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        else:
            self.device = torch.device(device)

        print(f"使用设备: {self.device}")

        # 加载分割模型
        print(f"加载分割模型: {segment_model_path}")
        self.segment_processor = VideoSegmentProcessor(
            model_path=segment_model_path,
            confidence_threshold=segment_conf,
            use_ema=True
        )

        # 加载时序分类模型
        print(f"加载时序分类模型: {temporal_model_path}")
        self.temporal_model = create_model(temporal_model_path)
        self.temporal_model = self.temporal_model.to(self.device)
        self.temporal_model.eval()

        total_params = sum(p.numel() for p in self.temporal_model.parameters())
        print(f"时序模型参数量: {total_params:,}")

    def process_frames(self, frames: List[np.ndarray]) -> FireDetectionOutput:
        """
        处理一批帧进行火灾检测

        Args:
            frames: 帧列表，每帧为 (H, W, 3) BGR 格式

        Returns:
            FireDetectionOutput 检测结果
        """
        if len(frames) < self.seq_length:
            return FireDetectionOutput(
                result=DetectionResult.NO_DETECTION,
                confidence=0.0,
                message=f"帧数不足: {len(frames)} < {self.seq_length}",
                frame_count=len(frames),
                detections=[]
            )

        # Step 1: 调整帧尺寸
        resized_frames = []
        for frame in frames:
            if frame.shape[:2] != self.frame_size:
                resized = cv2.resize(frame, (self.frame_size[1], self.frame_size[0]),
                                     interpolation=cv2.INTER_LINEAR)
            else:
                resized = frame
            resized_frames.append(resized)

        # Step 2: 使用分割模型检测火焰/烟雾
        processed_frames = []
        all_detections = []
        has_detection = False

        for processed in self.segment_processor.process_frames(
            resized_frames, skip_no_detection=False, force_mode=ROIMode.MASK
        ):
            if processed is not None and processed.has_detections:
                has_detection = True
                processed_frames.append(processed)
                all_detections.extend(processed.detections)
            else:
                processed_frames.append(processed)

        # Step 3: 检查是否有检测目标
        if not has_detection:
            return FireDetectionOutput(
                result=DetectionResult.NO_DETECTION,
                confidence=0.0,
                message="未检测到火焰或烟雾",
                frame_count=len(frames),
                detections=[]
            )

        # Step 4: 准备时序模型输入
        temporal_input = []
        for pf in processed_frames:
            if pf is not None:
                frame_rgb = cv2.cvtColor(pf.data, cv2.COLOR_BGR2RGB)
                frame_chw = frame_rgb.transpose(2, 0, 1).astype(np.float32) / 255.0
                temporal_input.append(frame_chw)
            else:
                temporal_input.append(np.zeros((3, self.frame_size[0], self.frame_size[1]),
                                               dtype=np.float32))

        # 确保有足够的帧，不足时用空帧填充
        while len(temporal_input) < self.seq_length:
            temporal_input.append(temporal_input[-1] if temporal_input else
                                  np.zeros((3, self.frame_size[0], self.frame_size[1]),
                                           dtype=np.float32))

        # 只保留最近的 N 帧，N 为 seq_length
        temporal_input = temporal_input[-self.seq_length:]

        # Step 5: 时序分类推理
        frames_tensor = torch.from_numpy(np.stack(temporal_input, axis=0))
        frames_tensor = frames_tensor.unsqueeze(0).to(self.device)

        # 计算热力图和概率
        with torch.no_grad():
            heatmap = self.temporal_model(frames_tensor)
            prob = heatmap_to_prob(heatmap).item()

        heatmap_np = heatmap[0, 0].cpu().numpy()

        # Step 6: 判断结果
        if prob > self.temporal_threshold:
            return FireDetectionOutput(
                result=DetectionResult.FIRE_DETECTED,
                confidence=prob,
                message=f"[警告] 发现火灾! 动态特征置信度: {prob:.3f}",
                frame_count=len(frames),
                detections=all_detections,
                heatmap=heatmap_np
            )
        else:
            return FireDetectionOutput(
                result=DetectionResult.STATIC_SUSPECTED,
                confidence=prob,
                message=f"未发现火灾，疑似静态图片 (静态置信度: {1-prob:.3f})",
                frame_count=len(frames),
                detections=all_detections,
                heatmap=heatmap_np
            )

# %% [markdown]
# ## 4. 视频源类

# %%
class VideoSource:
    """视频源封装类，支持视频文件和 RTSP 流"""

    def __init__(self, source: str, loop: bool = False):
        """
        初始化视频源

        Args:
            source: 视频文件路径或 RTSP 流地址
            loop: 是否循环播放（仅对视频文件有效）
        """
        self.source = source
        self.loop = loop
        self.is_rtsp = source.lower().startswith('rtsp://')
        self.cap = None
        self.frame_count = 0
        self.fps = 0
        self._open()

    def _open(self):
        """打开视频源"""
        self.cap = cv2.VideoCapture(self.source)
        if not self.cap.isOpened():
            raise ValueError(f"无法打开视频源: {self.source}")

        self.fps = self.cap.get(cv2.CAP_PROP_FPS) or 30
        if not self.is_rtsp:
            self.frame_count = int(self.cap.get(cv2.CAP_PROP_FRAME_COUNT))

    def read_frames(self, count: int) -> List[np.ndarray]:
        """读取指定数量的帧"""
        frames = []
        for _ in range(count):
            ret, frame = self.cap.read()
            if not ret:
                if self.loop and not self.is_rtsp:
                    self.cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
                    ret, frame = self.cap.read()
                    if not ret:
                        break
                else:
                    break
            frames.append(frame)
        return frames

    def skip_frames(self, count: int):
        """跳过指定数量的帧"""
        for _ in range(count):
            ret, _ = self.cap.read()
            if not ret:
                break

    def release(self):
        """释放视频源"""
        if self.cap is not None:
            self.cap.release()

    @property
    def is_opened(self) -> bool:
        return self.cap is not None and self.cap.isOpened()

# %% [markdown]
# ## 5. 可视化函数

# %%
def visualize_result(
    frame: np.ndarray,
    output: FireDetectionOutput,
    figsize: Tuple[int, int] = (12, 5),
    heatmap_threshold: float = 0.5,
    blink_frame: int = 0
):
    """
    可视化检测结果

    Args:
        frame: 原始帧 (BGR)
        output: 检测结果
        figsize: 图像尺寸
        heatmap_threshold: heatmap 高热区域阈值 (归一化后)
        blink_frame: 闪烁帧计数器，用于控制红框闪烁效果 (偶数显示，奇数隐藏)
    """
    fig, axes = plt.subplots(1, 2 if output.heatmap is not None else 1, figsize=figsize)
    
    if output.heatmap is not None:
        ax1, ax2 = axes
    else:
        ax1 = axes

    # 复制帧用于绘制
    frame_draw = frame.copy()
    frame_rgb = cv2.cvtColor(frame_draw, cv2.COLOR_BGR2RGB)
    
    # 归一化 heatmap 用于判断高热区域
    heatmap_normalized = None
    if output.heatmap is not None:
        heatmap_min = output.heatmap.min()
        heatmap_max = output.heatmap.max()
        if heatmap_max > heatmap_min:
            heatmap_normalized = (output.heatmap - heatmap_min) / (heatmap_max - heatmap_min)
        else:
            heatmap_normalized = np.zeros_like(output.heatmap)
    
    # 绘制检测框
    for det in output.detections:
        bbox = det.get('bbox')  # [x1, y1, x2, y2]
        class_name = det.get('class_name', '').lower()
        
        if bbox is None:
            continue
            
        x1, y1, x2, y2 = [int(v) for v in bbox]
        
        # 根据类别选择颜色：火焰=黄色，烟雾=绿色
        if 'fire' in class_name or '火' in class_name:
            color = (255, 255, 0)  # 黄色 (RGB)
            label = "Fire"
        elif 'smoke' in class_name or '烟' in class_name:
            color = (0, 255, 0)    # 绿色 (RGB)
            label = "Smoke"
        else:
            color = (255, 165, 0)  # 橙色 (RGB)
            label = class_name
        
        # 检查是否需要用红色闪烁框标记（heatmap 高热区域）
        use_red_blink = False
        if (output.result == DetectionResult.FIRE_DETECTED and 
            heatmap_normalized is not None):
            # 计算 bbox 中心点在 heatmap 中的位置
            bbox_cx = (x1 + x2) // 2
            bbox_cy = (y1 + y2) // 2
            
            # 将 bbox 坐标映射到 heatmap 坐标
            h_frame, w_frame = frame.shape[:2]
            h_heatmap, w_heatmap = heatmap_normalized.shape
            
            hm_x = int(bbox_cx * w_heatmap / w_frame)
            hm_y = int(bbox_cy * h_heatmap / h_frame)
            
            # 确保坐标在范围内
            hm_x = max(0, min(hm_x, w_heatmap - 1))
            hm_y = max(0, min(hm_y, h_heatmap - 1))
            
            # 检查该区域的 heatmap 值是否超过阈值
            # 使用 bbox 对应区域的平均值
            hm_x1 = int(x1 * w_heatmap / w_frame)
            hm_y1 = int(y1 * h_heatmap / h_frame)
            hm_x2 = int(x2 * w_heatmap / w_frame)
            hm_y2 = int(y2 * h_heatmap / h_frame)
            
            hm_x1 = max(0, min(hm_x1, w_heatmap - 1))
            hm_y1 = max(0, min(hm_y1, h_heatmap - 1))
            hm_x2 = max(0, min(hm_x2, w_heatmap))
            hm_y2 = max(0, min(hm_y2, h_heatmap))
            
            if hm_x2 > hm_x1 and hm_y2 > hm_y1:
                region_mean = heatmap_normalized[hm_y1:hm_y2, hm_x1:hm_x2].mean()
                if region_mean > heatmap_threshold:
                    use_red_blink = True
        
        # 绘制边框
        if use_red_blink:
            # 红色闪烁框 - 根据 blink_frame 决定是否显示
            if blink_frame % 2 == 0:
                # 绘制红色粗框
                cv2.rectangle(frame_rgb, (x1, y1), (x2, y2), (255, 0, 0), 4)
                # 添加警告标签
                cv2.putText(frame_rgb, "FIRE!", (x1, y1 - 10),
                           cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 0, 0), 2)
        else:
            # 普通颜色框
            cv2.rectangle(frame_rgb, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame_rgb, label, (x1, y1 - 5),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    # 显示带标注的帧
    ax1.imshow(frame_rgb)
    
    # 设置标题颜色
    if output.result == DetectionResult.FIRE_DETECTED:
        title_color = 'red'
        status = 'FIRE DETECTED!'
    elif output.result == DetectionResult.STATIC_SUSPECTED:
        title_color = 'orange'
        status = 'Static Suspected'
    else:
        title_color = 'green'
        status = 'No Detection'
    
    ax1.set_title(f"{status}\nConfidence: {output.confidence:.3f}", 
                  color=title_color, fontsize=14, fontweight='bold')
    ax1.axis('off')

    # 显示热力图（独立显示，不叠加）
    if output.heatmap is not None:
        im = ax2.imshow(output.heatmap, cmap='jet', interpolation='bilinear')
        ax2.set_title('Temporal Heatmap', fontsize=12)
        ax2.axis('off')
        plt.colorbar(im, ax=ax2, fraction=0.046, pad=0.04)

    plt.tight_layout()
    plt.show()


def show_detection_summary(stats: dict):
    """显示检测统计摘要"""
    print("\n" + "=" * 50)
    print("检测统计")
    print("=" * 50)
    print(f"  处理批次: {stats['batch_count']}")
    print(f"  火灾检出: {stats['fire_count']} 次")
    print(f"  静态疑似: {stats['static_count']} 次")
    print(f"  无检测: {stats['no_detection_count']} 次")
    print("=" * 50)

# %% [markdown]
# ## 6. 配置参数

# %%
# ============ 配置参数 ============

# 输入源 (视频文件路径或 RTSP 流地址)
VIDEO_SOURCE = "D03_20211221160820.mp4"  # 修改为你的视频路径

# 模型路径
SEGMENT_MODEL_PATH = "segment.pt"   # YOLO 分割模型
TEMPORAL_MODEL_PATH = "convlstm.pth"  # 时序分类模型

# 检测参数
SEQ_LENGTH = 10          # 每次处理的帧数
FRAME_SIZE = (640, 640)  # 帧尺寸 (H, W)
SEGMENT_CONF = 0.5       # 分割模型置信度阈值
TEMPORAL_THRESHOLD = 0.5 # 时序分类阈值

# 设备
DEVICE = 'auto'  # 'cuda', 'cpu', 或 'auto'

# 处理参数
SKIP_FRAMES = 0    # 每次检测后跳过的帧数
MAX_BATCHES = None # 最大处理批次数 (设为 None 则处理整个视频)
LOOP_VIDEO = False # 是否循环播放视频

# 输出设置
OUTPUT_VIDEO_PATH = "output.mp4"         # 输出视频路径
PREVIEW_OUTPUT_DIR = "preview_frames"    # 中间结果图片保存目录
PREVIEW_INTERVAL_SEC = 1.0               # 每隔多少秒保存一张预览图 (默认1秒)

# %% [markdown]
# ## 7. 初始化检测器

# %%
print("=" * 50)
print("火灾检测系统初始化")
print("=" * 50)

detector = FireDetector(
    segment_model_path=SEGMENT_MODEL_PATH,
    temporal_model_path=TEMPORAL_MODEL_PATH,
    seq_length=SEQ_LENGTH,
    frame_size=FRAME_SIZE,
    segment_conf=SEGMENT_CONF,
    temporal_threshold=TEMPORAL_THRESHOLD,
    device=DEVICE
)

print("\n初始化完成!")
# Out:
# ==================================================
# 火灾检测系统初始化
# ==================================================
# 使用设备: cuda
# 加载分割模型: segment.pt
# 加载时序分类模型: convlstm.pth
# 时序模型参数量: 281,985
#
# 初始化完成!

# %% [markdown]
# ## 8. 运行检测

# %%
# 打开视频源
print(f"打开视频源: {VIDEO_SOURCE}")
video_source = VideoSource(VIDEO_SOURCE, loop=LOOP_VIDEO)
print(f"视频 FPS: {video_source.fps:.1f}")
if video_source.frame_count > 0:
    print(f"视频总帧数: {video_source.frame_count}")
    total_duration = video_source.frame_count / video_source.fps
    print(f"视频时长: {total_duration:.1f}秒")

# 输出视频设置
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out_writer = None  # 延迟初始化，等获取第一帧尺寸

# 创建预览图片输出目录
preview_dir = Path(PREVIEW_OUTPUT_DIR)
preview_dir.mkdir(exist_ok=True)
print(f"预览图片保存目录: {preview_dir.absolute()}")

# 计算预览采样间隔 (每隔多少帧保存一张图)
preview_frame_interval = int(video_source.fps * PREVIEW_INTERVAL_SEC)
print(f"预览采样: 每 {PREVIEW_INTERVAL_SEC} 秒 ({preview_frame_interval} 帧) 保存一张图")

# 统计变量
stats = {
    'batch_count': 0,
    'fire_count': 0,
    'static_count': 0,
    'no_detection_count': 0
}

def draw_result_on_frame(frame: np.ndarray, output: FireDetectionOutput, 
                         frame_idx: int = 0, video_time: float = 0.0,
                         heatmap_threshold: float = 0.5) -> np.ndarray:
    """在帧上绘制检测结果，返回带标注的帧"""
    frame_draw = frame.copy()
    h_frame, w_frame = frame.shape[:2]
    
    # 模型推理尺寸 (bbox 坐标基于此尺寸)
    model_size = FRAME_SIZE[0]  # 640
    
    # 计算缩放比例
    scale_x = w_frame / model_size
    scale_y = h_frame / model_size
    
    # 归一化 heatmap
    heatmap_normalized = None
    if output.heatmap is not None:
        heatmap_min = output.heatmap.min()
        heatmap_max = output.heatmap.max()
        if heatmap_max > heatmap_min:
            heatmap_normalized = (output.heatmap - heatmap_min) / (heatmap_max - heatmap_min)
        else:
            heatmap_normalized = np.zeros_like(output.heatmap)
    
    # 绘制检测框
    for det in output.detections:
        bbox = det.get('bbox')
        class_name = det.get('class_name', '').lower()
        
        if bbox is None:
            continue
        
        # 将 bbox 从模型尺寸 (640x640) 缩放到原始帧尺寸
        x1 = int(bbox[0] * scale_x)
        y1 = int(bbox[1] * scale_y)
        x2 = int(bbox[2] * scale_x)
        y2 = int(bbox[3] * scale_y)
        
        # 确保坐标在有效范围内
        x1 = max(0, min(x1, w_frame - 1))
        y1 = max(0, min(y1, h_frame - 1))
        x2 = max(0, min(x2, w_frame))
        y2 = max(0, min(y2, h_frame))
        
        # 根据类别选择颜色 (BGR)
        if 'fire' in class_name or '火' in class_name:
            color = (0, 255, 255)  # 黄色
            label = "Fire"
        elif 'smoke' in class_name or '烟' in class_name:
            color = (0, 255, 0)    # 绿色
            label = "Smoke"
        else:
            color = (0, 165, 255)  # 橙色
            label = class_name
        
        # 检查是否需要红色框 (火灾检出且在高热区域)
        use_red = False
        if output.result == DetectionResult.FIRE_DETECTED and heatmap_normalized is not None:
            h_heatmap, w_heatmap = heatmap_normalized.shape
            
            # bbox 坐标转换到 heatmap 坐标 (使用原始 bbox，因为都是基于 640x640)
            hm_x1 = int(bbox[0] * w_heatmap / model_size)
            hm_y1 = int(bbox[1] * h_heatmap / model_size)
            hm_x2 = int(bbox[2] * w_heatmap / model_size)
            hm_y2 = int(bbox[3] * h_heatmap / model_size)
            
            hm_x1 = max(0, min(hm_x1, w_heatmap - 1))
            hm_y1 = max(0, min(hm_y1, h_heatmap - 1))
            hm_x2 = max(0, min(hm_x2, w_heatmap))
            hm_y2 = max(0, min(hm_y2, h_heatmap))
            
            if hm_x2 > hm_x1 and hm_y2 > hm_y1:
                region_mean = heatmap_normalized[hm_y1:hm_y2, hm_x1:hm_x2].mean()
                if region_mean > heatmap_threshold:
                    use_red = True
        
        # 绘制边框
        if use_red:
            cv2.rectangle(frame_draw, (x1, y1), (x2, y2), (0, 0, 255), 4)
            cv2.putText(frame_draw, "FIRE!", (x1, y1 - 10),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)
        else:
            cv2.rectangle(frame_draw, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame_draw, label, (x1, y1 - 5),
                       cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)
    
    # 添加状态文字
    if output.result == DetectionResult.FIRE_DETECTED:
        status_text = f"FIRE DETECTED! Conf: {output.confidence:.2f}"
        status_color = (0, 0, 255)  # 红色
    elif output.result == DetectionResult.STATIC_SUSPECTED:
        status_text = f"Static Suspected ({1-output.confidence:.2f})"
        status_color = (0, 165, 255)  # 橙色
    else:
        status_text = "No Detection"
        status_color = (0, 255, 0)  # 绿色
    
    cv2.putText(frame_draw, status_text, (10, 30),
               cv2.FONT_HERSHEY_SIMPLEX, 1.0, status_color, 2)
    
    # 添加时间戳信息
    time_text = f"Frame: {frame_idx} | Time: {video_time:.1f}s"
    cv2.putText(frame_draw, time_text, (10, 60),
               cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
    
    return frame_draw

print("\n开始检测并生成视频...")
print("-" * 50)

global_frame_idx = 0
last_preview_frame = -preview_frame_interval  # 确保第一帧会被保存
preview_count = 0

try:
    while video_source.is_opened:
        if MAX_BATCHES is not None and stats['batch_count'] >= MAX_BATCHES:
            print(f"\n已达到最大批次数: {MAX_BATCHES}")
            break

        frames = video_source.read_frames(SEQ_LENGTH)
        if len(frames) == 0:
            break

        stats['batch_count'] += 1
        start_time = time.time()

        # 执行检测
        output = detector.process_frames(frames)
        elapsed = time.time() - start_time

        # 统计
        if output.result == DetectionResult.FIRE_DETECTED:
            stats['fire_count'] += 1
        elif output.result == DetectionResult.STATIC_SUSPECTED:
            stats['static_count'] += 1
        else:
            stats['no_detection_count'] += 1

        print(f"[Batch {stats['batch_count']:04d}] {output.message} ({elapsed:.2f}s)")

        # 将每一帧写入输出视频，并按间隔保存预览图
        for i, frame in enumerate(frames):
            current_frame_idx = global_frame_idx + i
            video_time = current_frame_idx / video_source.fps
            
            # 初始化 VideoWriter
            if out_writer is None:
                h, w = frame.shape[:2]
                out_writer = cv2.VideoWriter(OUTPUT_VIDEO_PATH, fourcc, video_source.fps, (w, h))
                print(f"输出视频: {OUTPUT_VIDEO_PATH} ({w}x{h} @ {video_source.fps:.1f}fps)")
            
            # 绘制检测结果
            annotated_frame = draw_result_on_frame(
                frame, output, 
                frame_idx=current_frame_idx, 
                video_time=video_time
            )
            out_writer.write(annotated_frame)
            
            # 按时间间隔保存预览图
            if current_frame_idx - last_preview_frame >= preview_frame_interval:
                preview_filename = preview_dir / f"frame_{current_frame_idx:06d}_{video_time:.1f}s.jpg"
                cv2.imwrite(str(preview_filename), annotated_frame)
                preview_count += 1
                last_preview_frame = current_frame_idx
        
        global_frame_idx += len(frames)

        if SKIP_FRAMES > 0:
            video_source.skip_frames(SKIP_FRAMES)
            global_frame_idx += SKIP_FRAMES

except KeyboardInterrupt:
    print("\n检测被中断")
finally:
    video_source.release()
    if out_writer is not None:
        out_writer.release()
        print(f"\n视频已保存: {OUTPUT_VIDEO_PATH}")

print(f"预览图片已保存: {preview_count} 张 -> {preview_dir.absolute()}")
show_detection_summary(stats)
print("\n检测完成!")
# Out:
# 打开视频源: D03_20211221160820.mp4
# 视频 FPS: 29.5
# 视频总帧数: 38373
# 视频时长: 1302.4秒
# 预览图片保存目录: /home/cxt/projects/fpa_fire_detection/preview_frames
# 预览采样: 每 1.0 秒 (29 帧) 保存一张图
#
# 开始检测并生成视频...
# --------------------------------------------------
# [Batch 0001] 未检测到火焰或烟雾 (0.27s)
# 输出视频: output.mp4 (1280x720 @ 29.5fps)
# [Batch 0002] 未检测到火焰或烟雾 (0.05s)
# [Batch 0003] 未检测到火焰或烟雾 (0.04s)
# [Batch 0004] 未检测到火焰或烟雾 (0.04s)
# [Batch 0005] 未检测到火焰或烟雾 (0.04s)
# [Batch 0006] 未检测到火焰或烟雾 (0.04s)
# [Batch 0007] 未检测到火焰或烟雾 (0.04s)
# [Batch 0008] 未检测到火焰或烟雾 (0.04s)
# [Batch 0009] 未检测到火焰或烟雾 (0.04s)
# [Batch 0010] 未检测到火焰或烟雾 (0.04s)
# [Batch 0011] 未检测到火焰或烟雾 (0.04s)
# [Batch 0012] 未检测到火焰或烟雾 (0.04s)
# [Batch 0013] 未检测到火焰或烟雾 (0.04s)
# [Batch 0014] 未检测到火焰或烟雾 (0.04s)
# [Batch 0015] 未检测到火焰或烟雾 (0.04s)
# [Batch 0016] 未检测到火焰或烟雾 (0.05s)
# [Batch 0017] 未检测到火焰或烟雾 (0.04s)
# [Batch 0018] 未检测到火焰或烟雾 (0.04s)
# [Batch 0019] 未检测到火焰或烟雾 (0.04s)
# [Batch 0020] 未检测到火焰或烟雾 (0.04s)
# [Batch 0021] 未检测到火焰或烟雾 (0.04s)
# [Batch 0022] 未检测到火焰或烟雾 (0.04s)
# [Batch 0023] 未检测到火焰或烟雾 (0.04s)
# [Batch 0024] 未检测到火焰或烟雾 (0.04s)
# [Batch 0025] 未检测到火焰或烟雾 (0.04s)
# [Batch 0026] 未检测到火焰或烟雾 (0.04s)
# [Batch 0027] 未检测到火焰或烟雾 (0.04s)
# [Batch 0028] 未检测到火焰或烟雾 (0.04s)
# [Batch 0029] 未检测到火焰或烟雾 (0.04s)
# [Batch 0030] 未检测到火焰或烟雾 (0.04s)
# [Batch 0031] 未检测到火焰或烟雾 (0.04s)
# [Batch 0032] 未检测到火焰或烟雾 (0.04s)
# [Batch 0033] 未检测到火焰或烟雾 (0.04s)
# [Batch 0034] 未检测到火焰或烟雾 (0.04s)
# [Batch 0035] 未检测到火焰或烟雾 (0.04s)
# [Batch 0036] 未检测到火焰或烟雾 (0.04s)
# [Batch 0037] 未检测到火焰或烟雾 (0.04s)
# [Batch 0038] 未检测到火焰或烟雾 (0.04s)
# [Batch 0039] 未检测到火焰或烟雾 (0.04s)
# [Batch 0040] 未检测到火焰或烟雾 (0.04s)
# [Batch 0041] 未检测到火焰或烟雾 (0.04s)
# [Batch 0042] 未检测到火焰或烟雾 (0.04s)
# [Batch 0043] 未检测到火焰或烟雾 (0.04s)
# [Batch 0044] 未检测到火焰或烟雾 (0.04s)
# [Batch 0045] 未检测到火焰或烟雾 (0.04s)
# [Batch 0046] 未检测到火焰或烟雾 (0.04s)
# [Batch 0047] 未检测到火焰或烟雾 (0.04s)
# [Batch 0048] 未检测到火焰或烟雾 (0.04s)
# [Batch 0049] 未检测到火焰或烟雾 (0.04s)
# [Batch 0050] 未检测到火焰或烟雾 (0.04s)
# [Batch 0051] 未检测到火焰或烟雾 (0.04s)
# [Batch 0052] 未检测到火焰或烟雾 (0.04s)
# [Batch 0053] 未检测到火焰或烟雾 (0.04s)
# [Batch 0054] 未检测到火焰或烟雾 (0.04s)
# [Batch 0055] 未检测到火焰或烟雾 (0.04s)
# [Batch 0056] 未检测到火焰或烟雾 (0.04s)
# [Batch 0057] 未检测到火焰或烟雾 (0.04s)
# [Batch 0058] 未检测到火焰或烟雾 (0.04s)
# [Batch 0059] 未检测到火焰或烟雾 (0.04s)
# [Batch 0060] 未检测到火焰或烟雾 (0.04s)
# [Batch 0061] 未检测到火焰或烟雾 (0.04s)
# [Batch 0062] 未检测到火焰或烟雾 (0.04s)
# [Batch 0063] 未检测到火焰或烟雾 (0.04s)
# [Batch 0064] 未检测到火焰或烟雾 (0.04s)
# [Batch 0065] 未检测到火焰或烟雾 (0.04s)
# [Batch 0066] 未检测到火焰或烟雾 (0.04s)
# [Batch 0067] 未检测到火焰或烟雾 (0.04s)
# [Batch 0068] 未检测到火焰或烟雾 (0.04s)
# [Batch 0069] 未检测到火焰或烟雾 (0.04s)
# [Batch 0070] 未检测到火焰或烟雾 (0.04s)
# [Batch 0071] 未检测到火焰或烟雾 (0.04s)
# [Batch 0072] 未检测到火焰或烟雾 (0.04s)
# [Batch 0073] 未检测到火焰或烟雾 (0.04s)
# [Batch 0074] 未检测到火焰或烟雾 (0.05s)
# [Batch 0075] 未检测到火焰或烟雾 (0.04s)
# [Batch 0076] 未检测到火焰或烟雾 (0.04s)
# [Batch 0077] 未检测到火焰或烟雾 (0.04s)
# [Batch 0078] 未检测到火焰或烟雾 (0.04s)
# [Batch 0079] 未检测到火焰或烟雾 (0.04s)
# [Batch 0080] 未检测到火焰或烟雾 (0.04s)
# [Batch 0081] 未检测到火焰或烟雾 (0.04s)
# [Batch 0082] 未检测到火焰或烟雾 (0.04s)
# [Batch 0083] 未检测到火焰或烟雾 (0.04s)
# [Batch 0084] 未检测到火焰或烟雾 (0.04s)
# [Batch 0085] 未检测到火焰或烟雾 (0.04s)
# [Batch 0086] 未检测到火焰或烟雾 (0.04s)
# [Batch 0087] 未检测到火焰或烟雾 (0.04s)
# [Batch 0088] 未检测到火焰或烟雾 (0.04s)
# [Batch 0089] 未检测到火焰或烟雾 (0.04s)
# [Batch 0090] 未检测到火焰或烟雾 (0.04s)
# [Batch 0091] 未检测到火焰或烟雾 (0.04s)
# [Batch 0092] 未检测到火焰或烟雾 (0.04s)
# [Batch 0093] 未检测到火焰或烟雾 (0.04s)
# [Batch 0094] 未检测到火焰或烟雾 (0.04s)
# [Batch 0095] 未检测到火焰或烟雾 (0.04s)
# [Batch 0096] 未检测到火焰或烟雾 (0.04s)
# [Batch 0097] 未检测到火焰或烟雾 (0.04s)
# [Batch 0098] 未检测到火焰或烟雾 (0.04s)
# [Batch 0099] 未检测到火焰或烟雾 (0.04s)
# [Batch 0100] 未检测到火焰或烟雾 (0.04s)
# [Batch 0101] 未检测到火焰或烟雾 (0.04s)
# [Batch 0102] 未检测到火焰或烟雾 (0.04s)
# [Batch 0103] 未检测到火焰或烟雾 (0.04s)
# [Batch 0104] 未检测到火焰或烟雾 (0.04s)
# [Batch 0105] 未检测到火焰或烟雾 (0.04s)
# [Batch 0106] 未检测到火焰或烟雾 (0.04s)
# [Batch 0107] 未检测到火焰或烟雾 (0.04s)
# [Batch 0108] 未检测到火焰或烟雾 (0.04s)
# [Batch 0109] 未检测到火焰或烟雾 (0.04s)
# [Batch 0110] 未检测到火焰或烟雾 (0.04s)
# [Batch 0111] 未检测到火焰或烟雾 (0.04s)
# [Batch 0112] 未检测到火焰或烟雾 (0.04s)
# [Batch 0113] 未检测到火焰或烟雾 (0.04s)
# [Batch 0114] 未检测到火焰或烟雾 (0.04s)
# [Batch 0115] 未检测到火焰或烟雾 (0.04s)
# [Batch 0116] 未检测到火焰或烟雾 (0.04s)
# [Batch 0117] 未检测到火焰或烟雾 (0.04s)
# [Batch 0118] 未检测到火焰或烟雾 (0.04s)
# [Batch 0119] 未检测到火焰或烟雾 (0.04s)
# [Batch 0120] 未检测到火焰或烟雾 (0.04s)
# [Batch 0121] 未检测到火焰或烟雾 (0.04s)
# [Batch 0122] 未检测到火焰或烟雾 (0.04s)
# [Batch 0123] 未检测到火焰或烟雾 (0.04s)
# [Batch 0124] 未检测到火焰或烟雾 (0.04s)
# [Batch 0125] 未检测到火焰或烟雾 (0.04s)
# [Batch 0126] 未检测到火焰或烟雾 (0.04s)
# [Batch 0127] 未检测到火焰或烟雾 (0.04s)
# [Batch 0128] 未检测到火焰或烟雾 (0.04s)
# [Batch 0129] 未检测到火焰或烟雾 (0.04s)
# [Batch 0130] 未检测到火焰或烟雾 (0.04s)
# [Batch 0131] 未检测到火焰或烟雾 (0.04s)
# [Batch 0132] 未检测到火焰或烟雾 (0.04s)
# [Batch 0133] 未检测到火焰或烟雾 (0.04s)
# [Batch 0134] 未检测到火焰或烟雾 (0.04s)
# [Batch 0135] 未检测到火焰或烟雾 (0.04s)
# [Batch 0136] 未检测到火焰或烟雾 (0.04s)
# [Batch 0137] 未检测到火焰或烟雾 (0.04s)
# [Batch 0138] 未检测到火焰或烟雾 (0.04s)
# [Batch 0139] 未检测到火焰或烟雾 (0.04s)
# [Batch 0140] 未检测到火焰或烟雾 (0.04s)
# [Batch 0141] 未检测到火焰或烟雾 (0.04s)
# [Batch 0142] 未检测到火焰或烟雾 (0.04s)
# [Batch 0143] 未检测到火焰或烟雾 (0.04s)
# [Batch 0144] 未检测到火焰或烟雾 (0.04s)
# [Batch 0145] 未检测到火焰或烟雾 (0.04s)
# [Batch 0146] 未检测到火焰或烟雾 (0.04s)
# [Batch 0147] 未检测到火焰或烟雾 (0.04s)
# [Batch 0148] 未检测到火焰或烟雾 (0.04s)
# [Batch 0149] 未检测到火焰或烟雾 (0.04s)
# [Batch 0150] 未检测到火焰或烟雾 (0.04s)
# [Batch 0151] 未检测到火焰或烟雾 (0.04s)
# [Batch 0152] 未检测到火焰或烟雾 (0.04s)
# [Batch 0153] 未检测到火焰或烟雾 (0.04s)
# [Batch 0154] 未检测到火焰或烟雾 (0.04s)
# [Batch 0155] 未检测到火焰或烟雾 (0.04s)
# [Batch 0156] 未检测到火焰或烟雾 (0.04s)
# [Batch 0157] 未检测到火焰或烟雾 (0.04s)
# [Batch 0158] 未检测到火焰或烟雾 (0.04s)
# [Batch 0159] 未检测到火焰或烟雾 (0.04s)
# [Batch 0160] 未检测到火焰或烟雾 (0.04s)
# [Batch 0161] 未检测到火焰或烟雾 (0.04s)
# [Batch 0162] 未检测到火焰或烟雾 (0.04s)
# [Batch 0163] 未检测到火焰或烟雾 (0.04s)
# [Batch 0164] 未检测到火焰或烟雾 (0.04s)
# [Batch 0165] 未检测到火焰或烟雾 (0.04s)
# [Batch 0166] 未检测到火焰或烟雾 (0.04s)
# [Batch 0167] 未检测到火焰或烟雾 (0.04s)
# [Batch 0168] 未检测到火焰或烟雾 (0.04s)
# [Batch 0169] 未检测到火焰或烟雾 (0.04s)
# [Batch 0170] 未检测到火焰或烟雾 (0.04s)
# [Batch 0171] 未检测到火焰或烟雾 (0.04s)
# [Batch 0172] 未检测到火焰或烟雾 (0.04s)
# [Batch 0173] 未检测到火焰或烟雾 (0.04s)
# [Batch 0174] 未检测到火焰或烟雾 (0.04s)
# [Batch 0175] 未检测到火焰或烟雾 (0.04s)
# [Batch 0176] 未检测到火焰或烟雾 (0.04s)
# [Batch 0177] 未检测到火焰或烟雾 (0.04s)
# [Batch 0178] 未检测到火焰或烟雾 (0.04s)
# [Batch 0179] 未检测到火焰或烟雾 (0.04s)
# [Batch 0180] 未检测到火焰或烟雾 (0.04s)
# [Batch 0181] 未检测到火焰或烟雾 (0.04s)
# [Batch 0182] 未检测到火焰或烟雾 (0.04s)
# [Batch 0183] 未检测到火焰或烟雾 (0.04s)
# [Batch 0184] 未检测到火焰或烟雾 (0.04s)
# [Batch 0185] 未检测到火焰或烟雾 (0.04s)
# [Batch 0186] 未检测到火焰或烟雾 (0.04s)
# [Batch 0187] 未检测到火焰或烟雾 (0.04s)
# [Batch 0188] 未检测到火焰或烟雾 (0.04s)
# [Batch 0189] 未检测到火焰或烟雾 (0.04s)
# [Batch 0190] 未检测到火焰或烟雾 (0.04s)
# [Batch 0191] 未检测到火焰或烟雾 (0.04s)
# [Batch 0192] 未检测到火焰或烟雾 (0.04s)
# [Batch 0193] 未检测到火焰或烟雾 (0.04s)
# [Batch 0194] 未检测到火焰或烟雾 (0.04s)
# [Batch 0195] 未检测到火焰或烟雾 (0.04s)
# [Batch 0196] 未检测到火焰或烟雾 (0.04s)
# [Batch 0197] 未检测到火焰或烟雾 (0.04s)
# [Batch 0198] 未检测到火焰或烟雾 (0.04s)
# [Batch 0199] 未检测到火焰或烟雾 (0.04s)
# [Batch 0200] 未检测到火焰或烟雾 (0.04s)
# [Batch 0201] 未检测到火焰或烟雾 (0.04s)
# [Batch 0202] 未检测到火焰或烟雾 (0.04s)
# [Batch 0203] 未检测到火焰或烟雾 (0.04s)
# [Batch 0204] 未检测到火焰或烟雾 (0.04s)
# [Batch 0205] 未检测到火焰或烟雾 (0.04s)
# [Batch 0206] 未检测到火焰或烟雾 (0.04s)
# [Batch 0207] 未检测到火焰或烟雾 (0.04s)
# [Batch 0208] 未检测到火焰或烟雾 (0.04s)
# [Batch 0209] 未检测到火焰或烟雾 (0.04s)
# [Batch 0210] 未检测到火焰或烟雾 (0.04s)
# [Batch 0211] 未检测到火焰或烟雾 (0.04s)
# [Batch 0212] 未检测到火焰或烟雾 (0.04s)
# [Batch 0213] 未检测到火焰或烟雾 (0.04s)
# [Batch 0214] 未检测到火焰或烟雾 (0.04s)
# [Batch 0215] 未检测到火焰或烟雾 (0.04s)
# [Batch 0216] 未检测到火焰或烟雾 (0.04s)
# [Batch 0217] 未检测到火焰或烟雾 (0.04s)
# [Batch 0218] 未检测到火焰或烟雾 (0.04s)
# [Batch 0219] 未检测到火焰或烟雾 (0.04s)
# [Batch 0220] 未检测到火焰或烟雾 (0.04s)
# [Batch 0221] 未检测到火焰或烟雾 (0.04s)
# [Batch 0222] 未检测到火焰或烟雾 (0.04s)
# [Batch 0223] 未检测到火焰或烟雾 (0.04s)
# [Batch 0224] 未检测到火焰或烟雾 (0.04s)
# [Batch 0225] 未检测到火焰或烟雾 (0.04s)
# [Batch 0226] 未检测到火焰或烟雾 (0.04s)
# [Batch 0227] 未检测到火焰或烟雾 (0.04s)
# [Batch 0228] 未检测到火焰或烟雾 (0.04s)
# [Batch 0229] 未检测到火焰或烟雾 (0.04s)
# [Batch 0230] 未检测到火焰或烟雾 (0.04s)
# [Batch 0231] 未检测到火焰或烟雾 (0.04s)
# [Batch 0232] 未检测到火焰或烟雾 (0.04s)
# [Batch 0233] 未检测到火焰或烟雾 (0.04s)
# [Batch 0234] 未检测到火焰或烟雾 (0.04s)
# [Batch 0235] 未检测到火焰或烟雾 (0.04s)
# [Batch 0236] 未检测到火焰或烟雾 (0.04s)
# [Batch 0237] 未检测到火焰或烟雾 (0.04s)
# [Batch 0238] 未检测到火焰或烟雾 (0.04s)
# [Batch 0239] 未检测到火焰或烟雾 (0.04s)
# [Batch 0240] 未检测到火焰或烟雾 (0.04s)
# [Batch 0241] 未检测到火焰或烟雾 (0.04s)
# [Batch 0242] 未检测到火焰或烟雾 (0.04s)
# [Batch 0243] 未检测到火焰或烟雾 (0.04s)
# [Batch 0244] 未检测到火焰或烟雾 (0.04s)
# [Batch 0245] 未检测到火焰或烟雾 (0.04s)
# [Batch 0246] 未检测到火焰或烟雾 (0.04s)
# [Batch 0247] 未检测到火焰或烟雾 (0.04s)
# [Batch 0248] 未检测到火焰或烟雾 (0.04s)
# [Batch 0249] 未检测到火焰或烟雾 (0.04s)
# [Batch 0250] 未检测到火焰或烟雾 (0.04s)
# [Batch 0251] 未检测到火焰或烟雾 (0.04s)
# [Batch 0252] 未检测到火焰或烟雾 (0.04s)
# [Batch 0253] 未检测到火焰或烟雾 (0.04s)
# [Batch 0254] 未检测到火焰或烟雾 (0.04s)
# [Batch 0255] 未检测到火焰或烟雾 (0.04s)
# [Batch 0256] 未检测到火焰或烟雾 (0.04s)
# [Batch 0257] 未检测到火焰或烟雾 (0.04s)
# [Batch 0258] 未检测到火焰或烟雾 (0.04s)
# [Batch 0259] 未检测到火焰或烟雾 (0.04s)
# [Batch 0260] 未检测到火焰或烟雾 (0.04s)
# [Batch 0261] 未检测到火焰或烟雾 (0.04s)
# [Batch 0262] 未检测到火焰或烟雾 (0.04s)
# [Batch 0263] 未检测到火焰或烟雾 (0.04s)
# [Batch 0264] 未检测到火焰或烟雾 (0.04s)
# [Batch 0265] 未检测到火焰或烟雾 (0.04s)
# [Batch 0266] 未检测到火焰或烟雾 (0.04s)
# [Batch 0267] 未检测到火焰或烟雾 (0.04s)
# [Batch 0268] 未检测到火焰或烟雾 (0.04s)
# [Batch 0269] 未检测到火焰或烟雾 (0.04s)
# [Batch 0270] 未检测到火焰或烟雾 (0.04s)
# [Batch 0271] 未检测到火焰或烟雾 (0.04s)
# [Batch 0272] 未检测到火焰或烟雾 (0.04s)
# [Batch 0273] 未检测到火焰或烟雾 (0.04s)
# [Batch 0274] 未检测到火焰或烟雾 (0.04s)
# [Batch 0275] 未检测到火焰或烟雾 (0.04s)
# [Batch 0276] 未检测到火焰或烟雾 (0.04s)
# [Batch 0277] 未检测到火焰或烟雾 (0.04s)
# [Batch 0278] 未检测到火焰或烟雾 (0.04s)
# [Batch 0279] 未检测到火焰或烟雾 (0.04s)
# [Batch 0280] 未检测到火焰或烟雾 (0.04s)
# [Batch 0281] 未检测到火焰或烟雾 (0.04s)
# [Batch 0282] 未检测到火焰或烟雾 (0.04s)
# [Batch 0283] 未检测到火焰或烟雾 (0.04s)
# [Batch 0284] 未检测到火焰或烟雾 (0.04s)
# [Batch 0285] 未检测到火焰或烟雾 (0.04s)
# [Batch 0286] 未检测到火焰或烟雾 (0.04s)
# [Batch 0287] 未检测到火焰或烟雾 (0.04s)
# [Batch 0288] 未检测到火焰或烟雾 (0.04s)
# [Batch 0289] 未检测到火焰或烟雾 (0.04s)
# [Batch 0290] 未检测到火焰或烟雾 (0.04s)
# [Batch 0291] 未检测到火焰或烟雾 (0.04s)
# [Batch 0292] 未检测到火焰或烟雾 (0.04s)
# [Batch 0293] 未检测到火焰或烟雾 (0.04s)
# [Batch 0294] 未检测到火焰或烟雾 (0.04s)
# [Batch 0295] 未检测到火焰或烟雾 (0.04s)
# [Batch 0296] 未检测到火焰或烟雾 (0.04s)
# [Batch 0297] 未检测到火焰或烟雾 (0.04s)
# [Batch 0298] 未检测到火焰或烟雾 (0.04s)
# [Batch 0299] 未检测到火焰或烟雾 (0.04s)
# [Batch 0300] 未检测到火焰或烟雾 (0.04s)
# [Batch 0301] 未检测到火焰或烟雾 (0.04s)
# [Batch 0302] 未检测到火焰或烟雾 (0.04s)
# [Batch 0303] 未检测到火焰或烟雾 (0.04s)
# [Batch 0304] 未检测到火焰或烟雾 (0.04s)
# [Batch 0305] 未检测到火焰或烟雾 (0.04s)
# [Batch 0306] 未检测到火焰或烟雾 (0.04s)
# [Batch 0307] 未检测到火焰或烟雾 (0.04s)
# [Batch 0308] 未检测到火焰或烟雾 (0.04s)
# [Batch 0309] 未检测到火焰或烟雾 (0.04s)
# [Batch 0310] 未检测到火焰或烟雾 (0.04s)
# [Batch 0311] 未检测到火焰或烟雾 (0.04s)
# [Batch 0312] 未检测到火焰或烟雾 (0.04s)
# [Batch 0313] 未检测到火焰或烟雾 (0.04s)
# [Batch 0314] 未检测到火焰或烟雾 (0.04s)
# [Batch 0315] 未检测到火焰或烟雾 (0.04s)
# [Batch 0316] 未检测到火焰或烟雾 (0.04s)
# [Batch 0317] 未检测到火焰或烟雾 (0.04s)
# [Batch 0318] 未检测到火焰或烟雾 (0.04s)
# [Batch 0319] 未检测到火焰或烟雾 (0.04s)
# [Batch 0320] 未检测到火焰或烟雾 (0.04s)
# [Batch 0321] 未检测到火焰或烟雾 (0.04s)
# [Batch 0322] 未检测到火焰或烟雾 (0.04s)
# [Batch 0323] 未检测到火焰或烟雾 (0.04s)
# [Batch 0324] 未检测到火焰或烟雾 (0.04s)
# [Batch 0325] 未检测到火焰或烟雾 (0.04s)
# [Batch 0326] 未检测到火焰或烟雾 (0.04s)
# [Batch 0327] 未检测到火焰或烟雾 (0.04s)
# [Batch 0328] 未检测到火焰或烟雾 (0.04s)
# [Batch 0329] 未检测到火焰或烟雾 (0.04s)
# [Batch 0330] 未检测到火焰或烟雾 (0.04s)
# [Batch 0331] 未检测到火焰或烟雾 (0.04s)
# [Batch 0332] 未检测到火焰或烟雾 (0.04s)
# [Batch 0333] 未检测到火焰或烟雾 (0.04s)
# [Batch 0334] 未检测到火焰或烟雾 (0.04s)
# [Batch 0335] 未检测到火焰或烟雾 (0.04s)
# [Batch 0336] 未检测到火焰或烟雾 (0.04s)
# [Batch 0337] 未检测到火焰或烟雾 (0.04s)
# [Batch 0338] 未检测到火焰或烟雾 (0.04s)
# [Batch 0339] 未检测到火焰或烟雾 (0.04s)
# [Batch 0340] 未检测到火焰或烟雾 (0.04s)
# [Batch 0341] 未检测到火焰或烟雾 (0.04s)
# [Batch 0342] 未检测到火焰或烟雾 (0.04s)
# [Batch 0343] 未检测到火焰或烟雾 (0.04s)
# [Batch 0344] 未检测到火焰或烟雾 (0.04s)
# [Batch 0345] 未检测到火焰或烟雾 (0.04s)
# [Batch 0346] 未检测到火焰或烟雾 (0.04s)
# [Batch 0347] 未检测到火焰或烟雾 (0.04s)
# [Batch 0348] 未检测到火焰或烟雾 (0.04s)
# [Batch 0349] 未检测到火焰或烟雾 (0.04s)
# [Batch 0350] 未检测到火焰或烟雾 (0.04s)
# [Batch 0351] 未检测到火焰或烟雾 (0.04s)
# [Batch 0352] 未检测到火焰或烟雾 (0.04s)
# [Batch 0353] 未检测到火焰或烟雾 (0.04s)
# [Batch 0354] 未检测到火焰或烟雾 (0.04s)
# [Batch 0355] 未检测到火焰或烟雾 (0.04s)
# [Batch 0356] 未检测到火焰或烟雾 (0.04s)
# [Batch 0357] 未检测到火焰或烟雾 (0.04s)
# [Batch 0358] 未检测到火焰或烟雾 (0.04s)
# [Batch 0359] 未检测到火焰或烟雾 (0.04s)
# [Batch 0360] 未检测到火焰或烟雾 (0.04s)
# [Batch 0361] 未检测到火焰或烟雾 (0.04s)
# [Batch 0362] 未检测到火焰或烟雾 (0.04s)
# [Batch 0363] 未检测到火焰或烟雾 (0.04s)
# [Batch 0364] 未检测到火焰或烟雾 (0.04s)
# [Batch 0365] 未检测到火焰或烟雾 (0.04s)
# [Batch 0366] 未检测到火焰或烟雾 (0.04s)
# [Batch 0367] 未检测到火焰或烟雾 (0.04s)
# [Batch 0368] 未检测到火焰或烟雾 (0.04s)
# [Batch 0369] 未检测到火焰或烟雾 (0.04s)
# [Batch 0370] 未检测到火焰或烟雾 (0.04s)
# [Batch 0371] 未检测到火焰或烟雾 (0.04s)
# [Batch 0372] 未检测到火焰或烟雾 (0.04s)
# [Batch 0373] 未检测到火焰或烟雾 (0.04s)
# [Batch 0374] 未检测到火焰或烟雾 (0.04s)
# [Batch 0375] 未检测到火焰或烟雾 (0.04s)
# [Batch 0376] 未检测到火焰或烟雾 (0.04s)
# [Batch 0377] 未检测到火焰或烟雾 (0.04s)
# [Batch 0378] 未检测到火焰或烟雾 (0.04s)
# [Batch 0379] 未检测到火焰或烟雾 (0.04s)
# [Batch 0380] 未检测到火焰或烟雾 (0.04s)
# [Batch 0381] 未检测到火焰或烟雾 (0.04s)
# [Batch 0382] 未检测到火焰或烟雾 (0.04s)
# [Batch 0383] 未检测到火焰或烟雾 (0.04s)
# [Batch 0384] 未检测到火焰或烟雾 (0.04s)
# [Batch 0385] 未检测到火焰或烟雾 (0.04s)
# [Batch 0386] 未检测到火焰或烟雾 (0.04s)
# [Batch 0387] 未检测到火焰或烟雾 (0.04s)
# [Batch 0388] 未检测到火焰或烟雾 (0.04s)
# [Batch 0389] 未检测到火焰或烟雾 (0.04s)
# [Batch 0390] 未检测到火焰或烟雾 (0.04s)
# [Batch 0391] 未检测到火焰或烟雾 (0.04s)
# [Batch 0392] 未检测到火焰或烟雾 (0.04s)
# [Batch 0393] 未检测到火焰或烟雾 (0.04s)
# [Batch 0394] 未检测到火焰或烟雾 (0.04s)
# [Batch 0395] 未检测到火焰或烟雾 (0.04s)
# [Batch 0396] 未检测到火焰或烟雾 (0.04s)
# [Batch 0397] 未检测到火焰或烟雾 (0.04s)
# [Batch 0398] 未检测到火焰或烟雾 (0.04s)
# [Batch 0399] 未检测到火焰或烟雾 (0.04s)
# [Batch 0400] 未检测到火焰或烟雾 (0.04s)
# [Batch 0401] 未检测到火焰或烟雾 (0.04s)
# [Batch 0402] 未检测到火焰或烟雾 (0.04s)
# [Batch 0403] 未检测到火焰或烟雾 (0.04s)
# [Batch 0404] 未检测到火焰或烟雾 (0.04s)
# [Batch 0405] 未检测到火焰或烟雾 (0.04s)
# [Batch 0406] 未检测到火焰或烟雾 (0.04s)
# [Batch 0407] 未检测到火焰或烟雾 (0.04s)
# [Batch 0408] 未检测到火焰或烟雾 (0.04s)
# [Batch 0409] 未检测到火焰或烟雾 (0.04s)
# [Batch 0410] 未检测到火焰或烟雾 (0.04s)
# [Batch 0411] 未检测到火焰或烟雾 (0.04s)
# [Batch 0412] 未检测到火焰或烟雾 (0.04s)
# [Batch 0413] 未检测到火焰或烟雾 (0.04s)
# [Batch 0414] 未检测到火焰或烟雾 (0.04s)
# [Batch 0415] 未检测到火焰或烟雾 (0.04s)
# [Batch 0416] 未检测到火焰或烟雾 (0.04s)
# [Batch 0417] 未检测到火焰或烟雾 (0.04s)
# [Batch 0418] 未检测到火焰或烟雾 (0.04s)
# [Batch 0419] 未检测到火焰或烟雾 (0.04s)
# [Batch 0420] 未检测到火焰或烟雾 (0.04s)
# [Batch 0421] 未检测到火焰或烟雾 (0.04s)
# [Batch 0422] 未检测到火焰或烟雾 (0.04s)
# [Batch 0423] 未检测到火焰或烟雾 (0.04s)
# [Batch 0424] 未检测到火焰或烟雾 (0.04s)
# [Batch 0425] 未检测到火焰或烟雾 (0.04s)
# [Batch 0426] 未检测到火焰或烟雾 (0.04s)
# [Batch 0427] 未检测到火焰或烟雾 (0.04s)
# [Batch 0428] 未检测到火焰或烟雾 (0.04s)
# [Batch 0429] 未检测到火焰或烟雾 (0.04s)
# [Batch 0430] 未检测到火焰或烟雾 (0.04s)
# [Batch 0431] 未检测到火焰或烟雾 (0.04s)
# [Batch 0432] 未检测到火焰或烟雾 (0.04s)
# [Batch 0433] 未检测到火焰或烟雾 (0.04s)
# [Batch 0434] 未检测到火焰或烟雾 (0.04s)
# [Batch 0435] 未检测到火焰或烟雾 (0.04s)
# [Batch 0436] 未检测到火焰或烟雾 (0.04s)
# [Batch 0437] 未检测到火焰或烟雾 (0.04s)
# [Batch 0438] 未检测到火焰或烟雾 (0.04s)
# [Batch 0439] 未检测到火焰或烟雾 (0.04s)
# [Batch 0440] 未检测到火焰或烟雾 (0.04s)
# [Batch 0441] 未检测到火焰或烟雾 (0.04s)
# [Batch 0442] 未检测到火焰或烟雾 (0.04s)
# [Batch 0443] 未检测到火焰或烟雾 (0.04s)
# [Batch 0444] 未检测到火焰或烟雾 (0.04s)
# [Batch 0445] 未检测到火焰或烟雾 (0.04s)
# [Batch 0446] 未检测到火焰或烟雾 (0.04s)
# [Batch 0447] 未检测到火焰或烟雾 (0.04s)
# [Batch 0448] 未检测到火焰或烟雾 (0.04s)
# [Batch 0449] 未检测到火焰或烟雾 (0.04s)
# [Batch 0450] 未检测到火焰或烟雾 (0.04s)
# [Batch 0451] 未检测到火焰或烟雾 (0.04s)
# [Batch 0452] 未检测到火焰或烟雾 (0.04s)
# [Batch 0453] 未检测到火焰或烟雾 (0.04s)
# [Batch 0454] 未检测到火焰或烟雾 (0.04s)
# [Batch 0455] 未检测到火焰或烟雾 (0.04s)
# [Batch 0456] 未检测到火焰或烟雾 (0.04s)
# [Batch 0457] 未检测到火焰或烟雾 (0.04s)
# [Batch 0458] 未检测到火焰或烟雾 (0.04s)
# [Batch 0459] 未检测到火焰或烟雾 (0.04s)
# [Batch 0460] 未检测到火焰或烟雾 (0.04s)
# [Batch 0461] 未检测到火焰或烟雾 (0.04s)
# [Batch 0462] 未检测到火焰或烟雾 (0.04s)
# [Batch 0463] 未检测到火焰或烟雾 (0.04s)
# [Batch 0464] 未检测到火焰或烟雾 (0.04s)
# [Batch 0465] 未检测到火焰或烟雾 (0.04s)
# [Batch 0466] 未检测到火焰或烟雾 (0.04s)
# [Batch 0467] 未检测到火焰或烟雾 (0.04s)
# [Batch 0468] 未检测到火焰或烟雾 (0.04s)
# [Batch 0469] 未检测到火焰或烟雾 (0.04s)
# [Batch 0470] 未检测到火焰或烟雾 (0.04s)
# [Batch 0471] 未检测到火焰或烟雾 (0.04s)
# [Batch 0472] 未检测到火焰或烟雾 (0.04s)
# [Batch 0473] 未检测到火焰或烟雾 (0.04s)
# [Batch 0474] 未检测到火焰或烟雾 (0.04s)
# [Batch 0475] 未检测到火焰或烟雾 (0.04s)
# [Batch 0476] 未检测到火焰或烟雾 (0.04s)
# [Batch 0477] 未检测到火焰或烟雾 (0.04s)
# [Batch 0478] 未检测到火焰或烟雾 (0.04s)
# [Batch 0479] 未检测到火焰或烟雾 (0.04s)
# [Batch 0480] 未检测到火焰或烟雾 (0.04s)
# [Batch 0481] 未检测到火焰或烟雾 (0.04s)
# [Batch 0482] 未检测到火焰或烟雾 (0.04s)
# [Batch 0483] 未检测到火焰或烟雾 (0.04s)
# [Batch 0484] 未检测到火焰或烟雾 (0.04s)
# [Batch 0485] 未检测到火焰或烟雾 (0.04s)
# [Batch 0486] 未检测到火焰或烟雾 (0.04s)
# [Batch 0487] 未检测到火焰或烟雾 (0.04s)
# [Batch 0488] 未检测到火焰或烟雾 (0.04s)
# [Batch 0489] 未检测到火焰或烟雾 (0.04s)
# [Batch 0490] 未检测到火焰或烟雾 (0.04s)
# [Batch 0491] 未检测到火焰或烟雾 (0.04s)
# [Batch 0492] 未检测到火焰或烟雾 (0.04s)
# [Batch 0493] 未检测到火焰或烟雾 (0.04s)
# [Batch 0494] 未检测到火焰或烟雾 (0.04s)
# [Batch 0495] 未检测到火焰或烟雾 (0.04s)
# [Batch 0496] 未检测到火焰或烟雾 (0.04s)
# [Batch 0497] 未检测到火焰或烟雾 (0.04s)
# [Batch 0498] 未检测到火焰或烟雾 (0.04s)
# [Batch 0499] 未检测到火焰或烟雾 (0.04s)
# [Batch 0500] 未检测到火焰或烟雾 (0.04s)
# [Batch 0501] 未检测到火焰或烟雾 (0.04s)
# [Batch 0502] 未检测到火焰或烟雾 (0.04s)
# [Batch 0503] 未检测到火焰或烟雾 (0.04s)
# [Batch 0504] 未检测到火焰或烟雾 (0.04s)
# [Batch 0505] 未检测到火焰或烟雾 (0.04s)
# [Batch 0506] 未检测到火焰或烟雾 (0.04s)
# [Batch 0507] 未检测到火焰或烟雾 (0.04s)
# [Batch 0508] 未检测到火焰或烟雾 (0.04s)
# [Batch 0509] 未检测到火焰或烟雾 (0.04s)
# [Batch 0510] 未检测到火焰或烟雾 (0.04s)
# [Batch 0511] 未检测到火焰或烟雾 (0.04s)
# [Batch 0512] 未检测到火焰或烟雾 (0.04s)
# [Batch 0513] 未检测到火焰或烟雾 (0.04s)
# [Batch 0514] 未检测到火焰或烟雾 (0.04s)
# [Batch 0515] 未检测到火焰或烟雾 (0.04s)
# [Batch 0516] 未检测到火焰或烟雾 (0.04s)
# [Batch 0517] 未检测到火焰或烟雾 (0.04s)
# [Batch 0518] 未检测到火焰或烟雾 (0.04s)
# [Batch 0519] 未检测到火焰或烟雾 (0.04s)
# [Batch 0520] 未检测到火焰或烟雾 (0.04s)
# [Batch 0521] 未检测到火焰或烟雾 (0.04s)
# [Batch 0522] 未检测到火焰或烟雾 (0.04s)
# [Batch 0523] 未检测到火焰或烟雾 (0.04s)
# [Batch 0524] 未检测到火焰或烟雾 (0.04s)
# [Batch 0525] 未检测到火焰或烟雾 (0.04s)
# [Batch 0526] 未检测到火焰或烟雾 (0.04s)
# [Batch 0527] 未检测到火焰或烟雾 (0.04s)
# [Batch 0528] 未检测到火焰或烟雾 (0.04s)
# [Batch 0529] 未检测到火焰或烟雾 (0.04s)
# [Batch 0530] 未检测到火焰或烟雾 (0.04s)
# [Batch 0531] 未检测到火焰或烟雾 (0.04s)
# [Batch 0532] 未检测到火焰或烟雾 (0.04s)
# [Batch 0533] 未检测到火焰或烟雾 (0.04s)
# [Batch 0534] 未检测到火焰或烟雾 (0.04s)
# [Batch 0535] 未检测到火焰或烟雾 (0.04s)
# [Batch 0536] 未检测到火焰或烟雾 (0.04s)
# [Batch 0537] 未检测到火焰或烟雾 (0.04s)
# [Batch 0538] 未检测到火焰或烟雾 (0.04s)
# [Batch 0539] 未检测到火焰或烟雾 (0.04s)
# [Batch 0540] 未检测到火焰或烟雾 (0.04s)
# [Batch 0541] 未检测到火焰或烟雾 (0.04s)
# [Batch 0542] 未检测到火焰或烟雾 (0.04s)
# [Batch 0543] 未检测到火焰或烟雾 (0.04s)
# [Batch 0544] 未检测到火焰或烟雾 (0.04s)
# [Batch 0545] 未检测到火焰或烟雾 (0.04s)
# [Batch 0546] 未检测到火焰或烟雾 (0.04s)
# [Batch 0547] 未检测到火焰或烟雾 (0.04s)
# [Batch 0548] 未检测到火焰或烟雾 (0.04s)
# [Batch 0549] 未检测到火焰或烟雾 (0.04s)
# [Batch 0550] 未检测到火焰或烟雾 (0.04s)
# [Batch 0551] 未检测到火焰或烟雾 (0.04s)
# [Batch 0552] 未检测到火焰或烟雾 (0.04s)
# [Batch 0553] 未检测到火焰或烟雾 (0.04s)
# [Batch 0554] 未检测到火焰或烟雾 (0.04s)
# [Batch 0555] 未检测到火焰或烟雾 (0.04s)
# [Batch 0556] 未检测到火焰或烟雾 (0.04s)
# [Batch 0557] 未检测到火焰或烟雾 (0.04s)
# [Batch 0558] 未检测到火焰或烟雾 (0.04s)
# [Batch 0559] 未检测到火焰或烟雾 (0.04s)
# [Batch 0560] 未检测到火焰或烟雾 (0.04s)
# [Batch 0561] 未检测到火焰或烟雾 (0.04s)
# [Batch 0562] 未检测到火焰或烟雾 (0.04s)
# [Batch 0563] 未检测到火焰或烟雾 (0.04s)
# [Batch 0564] 未检测到火焰或烟雾 (0.04s)
# [Batch 0565] 未检测到火焰或烟雾 (0.04s)
# [Batch 0566] 未检测到火焰或烟雾 (0.04s)
# [Batch 0567] 未检测到火焰或烟雾 (0.04s)
# [Batch 0568] 未检测到火焰或烟雾 (0.04s)
# [Batch 0569] 未检测到火焰或烟雾 (0.04s)
# [Batch 0570] 未检测到火焰或烟雾 (0.04s)
# [Batch 0571] 未检测到火焰或烟雾 (0.04s)
# [Batch 0572] 未检测到火焰或烟雾 (0.04s)
# [Batch 0573] 未检测到火焰或烟雾 (0.04s)
# [Batch 0574] 未检测到火焰或烟雾 (0.04s)
# [Batch 0575] 未检测到火焰或烟雾 (0.04s)
# [Batch 0576] 未检测到火焰或烟雾 (0.04s)
# [Batch 0577] 未检测到火焰或烟雾 (0.04s)
# [Batch 0578] 未检测到火焰或烟雾 (0.04s)
# [Batch 0579] 未检测到火焰或烟雾 (0.04s)
# [Batch 0580] 未检测到火焰或烟雾 (0.04s)
# [Batch 0581] 未检测到火焰或烟雾 (0.04s)
# [Batch 0582] 未检测到火焰或烟雾 (0.04s)
# [Batch 0583] 未检测到火焰或烟雾 (0.04s)
# [Batch 0584] 未检测到火焰或烟雾 (0.04s)
# [Batch 0585] 未检测到火焰或烟雾 (0.04s)
# [Batch 0586] 未检测到火焰或烟雾 (0.04s)
# [Batch 0587] 未检测到火焰或烟雾 (0.04s)
# [Batch 0588] 未检测到火焰或烟雾 (0.04s)
# [Batch 0589] 未检测到火焰或烟雾 (0.04s)
# [Batch 0590] 未检测到火焰或烟雾 (0.04s)
# [Batch 0591] 未检测到火焰或烟雾 (0.04s)
# [Batch 0592] 未检测到火焰或烟雾 (0.04s)
# [Batch 0593] 未检测到火焰或烟雾 (0.04s)
# [Batch 0594] 未检测到火焰或烟雾 (0.04s)
# [Batch 0595] 未检测到火焰或烟雾 (0.04s)
# [Batch 0596] 未检测到火焰或烟雾 (0.04s)
# [Batch 0597] 未检测到火焰或烟雾 (0.04s)
# [Batch 0598] 未检测到火焰或烟雾 (0.04s)
# [Batch 0599] 未检测到火焰或烟雾 (0.04s)
# [Batch 0600] 未检测到火焰或烟雾 (0.04s)
# [Batch 0601] 未检测到火焰或烟雾 (0.04s)
# [Batch 0602] 未检测到火焰或烟雾 (0.04s)
# [Batch 0603] 未检测到火焰或烟雾 (0.04s)
# [Batch 0604] 未检测到火焰或烟雾 (0.04s)
# [Batch 0605] 未检测到火焰或烟雾 (0.04s)
# [Batch 0606] 未检测到火焰或烟雾 (0.04s)
# [Batch 0607] 未检测到火焰或烟雾 (0.04s)
# [Batch 0608] 未检测到火焰或烟雾 (0.04s)
# [Batch 0609] 未检测到火焰或烟雾 (0.04s)
# [Batch 0610] 未检测到火焰或烟雾 (0.04s)
# [Batch 0611] 未检测到火焰或烟雾 (0.04s)
# [Batch 0612] 未检测到火焰或烟雾 (0.04s)
# [Batch 0613] 未检测到火焰或烟雾 (0.04s)
# [Batch 0614] 未检测到火焰或烟雾 (0.04s)
# [Batch 0615] 未检测到火焰或烟雾 (0.04s)
# [Batch 0616] 未检测到火焰或烟雾 (0.04s)
# [Batch 0617] 未检测到火焰或烟雾 (0.04s)
# [Batch 0618] 未检测到火焰或烟雾 (0.04s)
# [Batch 0619] 未检测到火焰或烟雾 (0.04s)
# [Batch 0620] 未检测到火焰或烟雾 (0.04s)
# [Batch 0621] 未检测到火焰或烟雾 (0.04s)
# [Batch 0622] 未检测到火焰或烟雾 (0.04s)
# [Batch 0623] 未检测到火焰或烟雾 (0.04s)
# [Batch 0624] 未检测到火焰或烟雾 (0.04s)
# [Batch 0625] 未检测到火焰或烟雾 (0.04s)
# [Batch 0626] 未检测到火焰或烟雾 (0.04s)
# [Batch 0627] 未检测到火焰或烟雾 (0.04s)
# [Batch 0628] 未检测到火焰或烟雾 (0.04s)
# [Batch 0629] 未检测到火焰或烟雾 (0.04s)
# [Batch 0630] 未检测到火焰或烟雾 (0.04s)
# [Batch 0631] 未检测到火焰或烟雾 (0.04s)
# [Batch 0632] 未检测到火焰或烟雾 (0.04s)
# [Batch 0633] 未检测到火焰或烟雾 (0.04s)
# [Batch 0634] 未检测到火焰或烟雾 (0.04s)
# [Batch 0635] 未检测到火焰或烟雾 (0.04s)
# [Batch 0636] 未检测到火焰或烟雾 (0.04s)
# [Batch 0637] 未检测到火焰或烟雾 (0.04s)
# [Batch 0638] 未检测到火焰或烟雾 (0.04s)
# [Batch 0639] 未检测到火焰或烟雾 (0.04s)
# [Batch 0640] 未检测到火焰或烟雾 (0.04s)
# [Batch 0641] 未检测到火焰或烟雾 (0.04s)
# [Batch 0642] 未检测到火焰或烟雾 (0.04s)
# [Batch 0643] 未检测到火焰或烟雾 (0.04s)
# [Batch 0644] 未检测到火焰或烟雾 (0.04s)
# [Batch 0645] 未检测到火焰或烟雾 (0.04s)
# [Batch 0646] 未检测到火焰或烟雾 (0.04s)
# [Batch 0647] 未检测到火焰或烟雾 (0.04s)
# [Batch 0648] 未检测到火焰或烟雾 (0.04s)
# [Batch 0649] 未检测到火焰或烟雾 (0.04s)
# [Batch 0650] 未检测到火焰或烟雾 (0.04s)
# [Batch 0651] 未检测到火焰或烟雾 (0.04s)
# [Batch 0652] 未检测到火焰或烟雾 (0.04s)
# [Batch 0653] 未检测到火焰或烟雾 (0.04s)
# [Batch 0654] 未检测到火焰或烟雾 (0.04s)
# [Batch 0655] 未检测到火焰或烟雾 (0.04s)
# [Batch 0656] 未检测到火焰或烟雾 (0.04s)
# [Batch 0657] 未检测到火焰或烟雾 (0.04s)
# [Batch 0658] 未检测到火焰或烟雾 (0.04s)
# [Batch 0659] 未检测到火焰或烟雾 (0.04s)
# [Batch 0660] 未检测到火焰或烟雾 (0.04s)
# [Batch 0661] 未检测到火焰或烟雾 (0.04s)
# [Batch 0662] 未检测到火焰或烟雾 (0.04s)
# [Batch 0663] 未检测到火焰或烟雾 (0.04s)
# [Batch 0664] 未检测到火焰或烟雾 (0.04s)
# [Batch 0665] 未检测到火焰或烟雾 (0.04s)
# [Batch 0666] 未检测到火焰或烟雾 (0.04s)
# [Batch 0667] 未检测到火焰或烟雾 (0.04s)
# [Batch 0668] 未检测到火焰或烟雾 (0.04s)
# [Batch 0669] 未检测到火焰或烟雾 (0.04s)
# [Batch 0670] 未检测到火焰或烟雾 (0.04s)
# [Batch 0671] 未检测到火焰或烟雾 (0.04s)
# [Batch 0672] 未检测到火焰或烟雾 (0.04s)
# [Batch 0673] 未检测到火焰或烟雾 (0.04s)
# [Batch 0674] 未检测到火焰或烟雾 (0.04s)
# [Batch 0675] 未检测到火焰或烟雾 (0.04s)
# [Batch 0676] 未检测到火焰或烟雾 (0.04s)
# [Batch 0677] 未检测到火焰或烟雾 (0.04s)
# [Batch 0678] 未检测到火焰或烟雾 (0.04s)
# [Batch 0679] 未检测到火焰或烟雾 (0.04s)
# [Batch 0680] 未检测到火焰或烟雾 (0.04s)
# [Batch 0681] 未检测到火焰或烟雾 (0.04s)
# [Batch 0682] 未检测到火焰或烟雾 (0.04s)
# [Batch 0683] 未检测到火焰或烟雾 (0.04s)
# [Batch 0684] 未检测到火焰或烟雾 (0.04s)
# [Batch 0685] 未检测到火焰或烟雾 (0.04s)
# [Batch 0686] 未检测到火焰或烟雾 (0.04s)
# [Batch 0687] 未检测到火焰或烟雾 (0.04s)
# [Batch 0688] 未检测到火焰或烟雾 (0.04s)
# [Batch 0689] 未检测到火焰或烟雾 (0.04s)
# [Batch 0690] 未检测到火焰或烟雾 (0.04s)
# [Batch 0691] 未检测到火焰或烟雾 (0.04s)
# [Batch 0692] 未检测到火焰或烟雾 (0.04s)
# [Batch 0693] 未检测到火焰或烟雾 (0.04s)
# [Batch 0694] 未检测到火焰或烟雾 (0.04s)
# [Batch 0695] 未检测到火焰或烟雾 (0.04s)
# [Batch 0696] 未检测到火焰或烟雾 (0.04s)
# [Batch 0697] 未检测到火焰或烟雾 (0.04s)
# [Batch 0698] 未检测到火焰或烟雾 (0.04s)
# [Batch 0699] 未检测到火焰或烟雾 (0.04s)
# [Batch 0700] 未检测到火焰或烟雾 (0.04s)
# [Batch 0701] 未检测到火焰或烟雾 (0.04s)
# [Batch 0702] 未检测到火焰或烟雾 (0.04s)
# [Batch 0703] 未检测到火焰或烟雾 (0.04s)
# [Batch 0704] 未检测到火焰或烟雾 (0.04s)
# [Batch 0705] 未检测到火焰或烟雾 (0.04s)
# [Batch 0706] 未检测到火焰或烟雾 (0.04s)
# [Batch 0707] 未检测到火焰或烟雾 (0.04s)
# [Batch 0708] 未检测到火焰或烟雾 (0.04s)
# [Batch 0709] 未检测到火焰或烟雾 (0.04s)
# [Batch 0710] 未检测到火焰或烟雾 (0.04s)
# [Batch 0711] 未检测到火焰或烟雾 (0.04s)
# [Batch 0712] 未检测到火焰或烟雾 (0.04s)
# [Batch 0713] 未检测到火焰或烟雾 (0.04s)
# [Batch 0714] 未检测到火焰或烟雾 (0.04s)
# [Batch 0715] 未检测到火焰或烟雾 (0.04s)
# [Batch 0716] 未检测到火焰或烟雾 (0.04s)
# [Batch 0717] 未检测到火焰或烟雾 (0.04s)
# [Batch 0718] 未检测到火焰或烟雾 (0.04s)
# [Batch 0719] 未检测到火焰或烟雾 (0.04s)
# [Batch 0720] 未检测到火焰或烟雾 (0.04s)
# [Batch 0721] 未检测到火焰或烟雾 (0.04s)
# [Batch 0722] 未检测到火焰或烟雾 (0.04s)
# [Batch 0723] 未检测到火焰或烟雾 (0.04s)
# [Batch 0724] 未检测到火焰或烟雾 (0.04s)
# [Batch 0725] 未检测到火焰或烟雾 (0.04s)
# [Batch 0726] 未检测到火焰或烟雾 (0.04s)
# [Batch 0727] 未检测到火焰或烟雾 (0.04s)
# [Batch 0728] 未检测到火焰或烟雾 (0.04s)
# [Batch 0729] 未检测到火焰或烟雾 (0.04s)
# [Batch 0730] 未检测到火焰或烟雾 (0.04s)
# [Batch 0731] 未检测到火焰或烟雾 (0.04s)
# [Batch 0732] 未检测到火焰或烟雾 (0.04s)
# [Batch 0733] 未检测到火焰或烟雾 (0.04s)
# [Batch 0734] 未检测到火焰或烟雾 (0.04s)
# [Batch 0735] 未检测到火焰或烟雾 (0.04s)
# [Batch 0736] 未检测到火焰或烟雾 (0.04s)
# [Batch 0737] 未检测到火焰或烟雾 (0.04s)
# [Batch 0738] 未检测到火焰或烟雾 (0.04s)
# [Batch 0739] 未检测到火焰或烟雾 (0.04s)
# [Batch 0740] 未检测到火焰或烟雾 (0.04s)
# [Batch 0741] 未检测到火焰或烟雾 (0.04s)
# [Batch 0742] 未检测到火焰或烟雾 (0.04s)
# [Batch 0743] 未检测到火焰或烟雾 (0.04s)
# [Batch 0744] 未检测到火焰或烟雾 (0.04s)
# [Batch 0745] [警告] 发现火灾! 动态特征置信度: 0.952 (0.08s)
# [Batch 0746] 未检测到火焰或烟雾 (0.04s)
# [Batch 0747] 未检测到火焰或烟雾 (0.04s)
# [Batch 0748] 未检测到火焰或烟雾 (0.04s)
# [Batch 0749] 未检测到火焰或烟雾 (0.04s)
# [Batch 0750] 未检测到火焰或烟雾 (0.04s)
# [Batch 0751] 未检测到火焰或烟雾 (0.04s)
# [Batch 0752] 未检测到火焰或烟雾 (0.04s)
# [Batch 0753] 未检测到火焰或烟雾 (0.04s)
# [Batch 0754] 未检测到火焰或烟雾 (0.04s)
# [Batch 0755] 未检测到火焰或烟雾 (0.04s)
# [Batch 0756] 未检测到火焰或烟雾 (0.04s)
# [Batch 0757] 未检测到火焰或烟雾 (0.04s)
# [Batch 0758] 未检测到火焰或烟雾 (0.04s)
# [Batch 0759] 未检测到火焰或烟雾 (0.04s)
# [Batch 0760] 未检测到火焰或烟雾 (0.04s)
# [Batch 0761] 未检测到火焰或烟雾 (0.04s)
# [Batch 0762] 未检测到火焰或烟雾 (0.04s)
# [Batch 0763] [警告] 发现火灾! 动态特征置信度: 0.977 (0.08s)
# [Batch 0764] [警告] 发现火灾! 动态特征置信度: 0.941 (0.07s)
# [Batch 0765] 未检测到火焰或烟雾 (0.04s)
# [Batch 0766] 未检测到火焰或烟雾 (0.04s)
# [Batch 0767] 未检测到火焰或烟雾 (0.04s)
# [Batch 0768] 未检测到火焰或烟雾 (0.04s)
# [Batch 0769] 未检测到火焰或烟雾 (0.04s)
# [Batch 0770] 未检测到火焰或烟雾 (0.04s)
# [Batch 0771] 未检测到火焰或烟雾 (0.04s)
# [Batch 0772] 未检测到火焰或烟雾 (0.04s)
# [Batch 0773] 未检测到火焰或烟雾 (0.04s)
# [Batch 0774] 未检测到火焰或烟雾 (0.04s)
# [Batch 0775] 未检测到火焰或烟雾 (0.04s)
# [Batch 0776] 未检测到火焰或烟雾 (0.04s)
# [Batch 0777] 未检测到火焰或烟雾 (0.04s)
# [Batch 0778] 未检测到火焰或烟雾 (0.04s)
# [Batch 0779] 未检测到火焰或烟雾 (0.04s)
# [Batch 0780] 未检测到火焰或烟雾 (0.04s)
# [Batch 0781] 未检测到火焰或烟雾 (0.04s)
# [Batch 0782] 未检测到火焰或烟雾 (0.04s)
# [Batch 0783] [警告] 发现火灾! 动态特征置信度: 0.939 (0.08s)
# [Batch 0784] [警告] 发现火灾! 动态特征置信度: 0.951 (0.11s)
# [Batch 0785] [警告] 发现火灾! 动态特征置信度: 0.956 (0.07s)
# [Batch 0786] 未检测到火焰或烟雾 (0.04s)
# [Batch 0787] 未检测到火焰或烟雾 (0.04s)
# [Batch 0788] 未检测到火焰或烟雾 (0.04s)
# [Batch 0789] 未检测到火焰或烟雾 (0.04s)
# [Batch 0790] 未检测到火焰或烟雾 (0.04s)
# [Batch 0791] 未检测到火焰或烟雾 (0.04s)
# [Batch 0792] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.06s)
# [Batch 0793] 未检测到火焰或烟雾 (0.04s)
# [Batch 0794] 未检测到火焰或烟雾 (0.04s)
# [Batch 0795] 未检测到火焰或烟雾 (0.04s)
# [Batch 0796] 未检测到火焰或烟雾 (0.04s)
# [Batch 0797] 未检测到火焰或烟雾 (0.04s)
# [Batch 0798] 未检测到火焰或烟雾 (0.04s)
# [Batch 0799] 未检测到火焰或烟雾 (0.04s)
# [Batch 0800] 未检测到火焰或烟雾 (0.04s)
# [Batch 0801] 未检测到火焰或烟雾 (0.04s)
# [Batch 0802] 未检测到火焰或烟雾 (0.04s)
# [Batch 0803] 未检测到火焰或烟雾 (0.04s)
# [Batch 0804] 未检测到火焰或烟雾 (0.04s)
# [Batch 0805] 未检测到火焰或烟雾 (0.04s)
# [Batch 0806] 未检测到火焰或烟雾 (0.04s)
# [Batch 0807] 未检测到火焰或烟雾 (0.04s)
# [Batch 0808] 未检测到火焰或烟雾 (0.04s)
# [Batch 0809] 未检测到火焰或烟雾 (0.04s)
# [Batch 0810] 未检测到火焰或烟雾 (0.04s)
# [Batch 0811] 未检测到火焰或烟雾 (0.04s)
# [Batch 0812] 未检测到火焰或烟雾 (0.04s)
# [Batch 0813] 未检测到火焰或烟雾 (0.04s)
# [Batch 0814] 未检测到火焰或烟雾 (0.04s)
# [Batch 0815] 未检测到火焰或烟雾 (0.04s)
# [Batch 0816] 未检测到火焰或烟雾 (0.04s)
# [Batch 0817] 未检测到火焰或烟雾 (0.04s)
# [Batch 0818] 未检测到火焰或烟雾 (0.04s)
# [Batch 0819] 未检测到火焰或烟雾 (0.04s)
# [Batch 0820] 未检测到火焰或烟雾 (0.04s)
# [Batch 0821] 未检测到火焰或烟雾 (0.04s)
# [Batch 0822] 未检测到火焰或烟雾 (0.04s)
# [Batch 0823] 未检测到火焰或烟雾 (0.04s)
# [Batch 0824] 未检测到火焰或烟雾 (0.04s)
# [Batch 0825] 未检测到火焰或烟雾 (0.04s)
# [Batch 0826] 未检测到火焰或烟雾 (0.04s)
# [Batch 0827] 未检测到火焰或烟雾 (0.04s)
# [Batch 0828] 未检测到火焰或烟雾 (0.04s)
# [Batch 0829] 未检测到火焰或烟雾 (0.04s)
# [Batch 0830] 未检测到火焰或烟雾 (0.04s)
# [Batch 0831] 未检测到火焰或烟雾 (0.04s)
# [Batch 0832] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.06s)
# [Batch 0833] [警告] 发现火灾! 动态特征置信度: 0.975 (0.08s)
# [Batch 0834] [警告] 发现火灾! 动态特征置信度: 0.951 (0.06s)
# [Batch 0835] 未检测到火焰或烟雾 (0.04s)
# [Batch 0836] 未检测到火焰或烟雾 (0.04s)
# [Batch 0837] 未检测到火焰或烟雾 (0.04s)
# [Batch 0838] 未检测到火焰或烟雾 (0.04s)
# [Batch 0839] 未检测到火焰或烟雾 (0.04s)
# [Batch 0840] 未检测到火焰或烟雾 (0.04s)
# [Batch 0841] 未检测到火焰或烟雾 (0.04s)
# [Batch 0842] [警告] 发现火灾! 动态特征置信度: 0.902 (0.10s)
# [Batch 0843] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 0844] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 0845] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 0846] 未发现火灾，疑似静态图片 (静态置信度: 0.834) (0.11s)
# [Batch 0847] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 0848] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 0849] [警告] 发现火灾! 动态特征置信度: 0.971 (0.09s)
# [Batch 0850] 未检测到火焰或烟雾 (0.04s)
# [Batch 0851] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.12s)
# [Batch 0852] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 0853] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 0854] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 0855] [警告] 发现火灾! 动态特征置信度: 0.953 (0.09s)
# [Batch 0856] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.10s)
# [Batch 0857] 未检测到火焰或烟雾 (0.04s)
# [Batch 0858] 未检测到火焰或烟雾 (0.04s)
# [Batch 0859] 未检测到火焰或烟雾 (0.04s)
# [Batch 0860] 未检测到火焰或烟雾 (0.04s)
# [Batch 0861] 未发现火灾，疑似静态图片 (静态置信度: 0.986) (0.07s)
# [Batch 0862] 未发现火灾，疑似静态图片 (静态置信度: 0.946) (0.09s)
# [Batch 0863] [警告] 发现火灾! 动态特征置信度: 0.958 (0.07s)
# [Batch 0864] [警告] 发现火灾! 动态特征置信度: 0.503 (0.06s)
# [Batch 0865] 未检测到火焰或烟雾 (0.04s)
# [Batch 0866] 未检测到火焰或烟雾 (0.04s)
# [Batch 0867] 未检测到火焰或烟雾 (0.04s)
# [Batch 0868] 未检测到火焰或烟雾 (0.04s)
# [Batch 0869] 未检测到火焰或烟雾 (0.04s)
# [Batch 0870] 未检测到火焰或烟雾 (0.04s)
# [Batch 0871] 未检测到火焰或烟雾 (0.04s)
# [Batch 0872] 未检测到火焰或烟雾 (0.04s)
# [Batch 0873] 未检测到火焰或烟雾 (0.04s)
# [Batch 0874] 未检测到火焰或烟雾 (0.04s)
# [Batch 0875] 未检测到火焰或烟雾 (0.05s)
# [Batch 0876] 未检测到火焰或烟雾 (0.04s)
# [Batch 0877] 未检测到火焰或烟雾 (0.04s)
# [Batch 0878] 未检测到火焰或烟雾 (0.04s)
# [Batch 0879] 未检测到火焰或烟雾 (0.04s)
# [Batch 0880] 未检测到火焰或烟雾 (0.04s)
# [Batch 0881] 未检测到火焰或烟雾 (0.04s)
# [Batch 0882] 未检测到火焰或烟雾 (0.04s)
# [Batch 0883] 未检测到火焰或烟雾 (0.04s)
# [Batch 0884] 未检测到火焰或烟雾 (0.04s)
# [Batch 0885] 未检测到火焰或烟雾 (0.04s)
# [Batch 0886] [警告] 发现火灾! 动态特征置信度: 0.969 (0.06s)
# [Batch 0887] [警告] 发现火灾! 动态特征置信度: 0.978 (0.06s)
# [Batch 0888] 未检测到火焰或烟雾 (0.04s)
# [Batch 0889] 未检测到火焰或烟雾 (0.04s)
# [Batch 0890] 未检测到火焰或烟雾 (0.04s)
# [Batch 0891] 未检测到火焰或烟雾 (0.04s)
# [Batch 0892] 未检测到火焰或烟雾 (0.04s)
# [Batch 0893] 未检测到火焰或烟雾 (0.04s)
# [Batch 0894] 未检测到火焰或烟雾 (0.04s)
# [Batch 0895] 未检测到火焰或烟雾 (0.04s)
# [Batch 0896] 未检测到火焰或烟雾 (0.04s)
# [Batch 0897] 未检测到火焰或烟雾 (0.04s)
# [Batch 0898] 未检测到火焰或烟雾 (0.04s)
# [Batch 0899] 未检测到火焰或烟雾 (0.04s)
# [Batch 0900] 未检测到火焰或烟雾 (0.04s)
# [Batch 0901] 未检测到火焰或烟雾 (0.04s)
# [Batch 0902] 未检测到火焰或烟雾 (0.04s)
# [Batch 0903] 未检测到火焰或烟雾 (0.04s)
# [Batch 0904] 未检测到火焰或烟雾 (0.04s)
# [Batch 0905] 未检测到火焰或烟雾 (0.04s)
# [Batch 0906] 未检测到火焰或烟雾 (0.04s)
# [Batch 0907] 未检测到火焰或烟雾 (0.04s)
# [Batch 0908] 未检测到火焰或烟雾 (0.04s)
# [Batch 0909] 未检测到火焰或烟雾 (0.04s)
# [Batch 0910] 未检测到火焰或烟雾 (0.04s)
# [Batch 0911] 未检测到火焰或烟雾 (0.04s)
# [Batch 0912] 未检测到火焰或烟雾 (0.04s)
# [Batch 0913] 未检测到火焰或烟雾 (0.04s)
# [Batch 0914] 未检测到火焰或烟雾 (0.04s)
# [Batch 0915] 未检测到火焰或烟雾 (0.04s)
# [Batch 0916] 未检测到火焰或烟雾 (0.04s)
# [Batch 0917] 未检测到火焰或烟雾 (0.04s)
# [Batch 0918] 未检测到火焰或烟雾 (0.04s)
# [Batch 0919] 未检测到火焰或烟雾 (0.04s)
# [Batch 0920] 未检测到火焰或烟雾 (0.04s)
# [Batch 0921] 未检测到火焰或烟雾 (0.04s)
# [Batch 0922] 未检测到火焰或烟雾 (0.04s)
# [Batch 0923] 未检测到火焰或烟雾 (0.04s)
# [Batch 0924] 未检测到火焰或烟雾 (0.04s)
# [Batch 0925] 未检测到火焰或烟雾 (0.04s)
# [Batch 0926] 未检测到火焰或烟雾 (0.04s)
# [Batch 0927] 未检测到火焰或烟雾 (0.04s)
# [Batch 0928] 未检测到火焰或烟雾 (0.04s)
# [Batch 0929] 未检测到火焰或烟雾 (0.04s)
# [Batch 0930] 未检测到火焰或烟雾 (0.04s)
# [Batch 0931] 未检测到火焰或烟雾 (0.04s)
# [Batch 0932] 未检测到火焰或烟雾 (0.04s)
# [Batch 0933] 未检测到火焰或烟雾 (0.04s)
# [Batch 0934] 未检测到火焰或烟雾 (0.04s)
# [Batch 0935] 未检测到火焰或烟雾 (0.04s)
# [Batch 0936] 未检测到火焰或烟雾 (0.04s)
# [Batch 0937] 未检测到火焰或烟雾 (0.04s)
# [Batch 0938] 未检测到火焰或烟雾 (0.04s)
# [Batch 0939] 未检测到火焰或烟雾 (0.04s)
# [Batch 0940] 未检测到火焰或烟雾 (0.04s)
# [Batch 0941] 未检测到火焰或烟雾 (0.04s)
# [Batch 0942] 未检测到火焰或烟雾 (0.04s)
# [Batch 0943] 未检测到火焰或烟雾 (0.04s)
# [Batch 0944] 未检测到火焰或烟雾 (0.04s)
# [Batch 0945] 未检测到火焰或烟雾 (0.04s)
# [Batch 0946] 未检测到火焰或烟雾 (0.04s)
# [Batch 0947] 未检测到火焰或烟雾 (0.04s)
# [Batch 0948] 未检测到火焰或烟雾 (0.04s)
# [Batch 0949] 未检测到火焰或烟雾 (0.04s)
# [Batch 0950] 未检测到火焰或烟雾 (0.04s)
# [Batch 0951] 未检测到火焰或烟雾 (0.04s)
# [Batch 0952] 未检测到火焰或烟雾 (0.04s)
# [Batch 0953] 未检测到火焰或烟雾 (0.04s)
# [Batch 0954] 未检测到火焰或烟雾 (0.04s)
# [Batch 0955] 未检测到火焰或烟雾 (0.04s)
# [Batch 0956] 未检测到火焰或烟雾 (0.04s)
# [Batch 0957] 未检测到火焰或烟雾 (0.04s)
# [Batch 0958] 未检测到火焰或烟雾 (0.04s)
# [Batch 0959] 未检测到火焰或烟雾 (0.04s)
# [Batch 0960] 未检测到火焰或烟雾 (0.04s)
# [Batch 0961] 未检测到火焰或烟雾 (0.04s)
# [Batch 0962] 未检测到火焰或烟雾 (0.04s)
# [Batch 0963] 未检测到火焰或烟雾 (0.04s)
# [Batch 0964] 未检测到火焰或烟雾 (0.04s)
# [Batch 0965] 未检测到火焰或烟雾 (0.04s)
# [Batch 0966] 未检测到火焰或烟雾 (0.04s)
# [Batch 0967] 未检测到火焰或烟雾 (0.04s)
# [Batch 0968] 未检测到火焰或烟雾 (0.04s)
# [Batch 0969] 未检测到火焰或烟雾 (0.04s)
# [Batch 0970] 未检测到火焰或烟雾 (0.04s)
# [Batch 0971] 未检测到火焰或烟雾 (0.04s)
# [Batch 0972] 未检测到火焰或烟雾 (0.04s)
# [Batch 0973] 未检测到火焰或烟雾 (0.04s)
# [Batch 0974] 未检测到火焰或烟雾 (0.04s)
# [Batch 0975] 未检测到火焰或烟雾 (0.04s)
# [Batch 0976] 未检测到火焰或烟雾 (0.04s)
# [Batch 0977] 未检测到火焰或烟雾 (0.04s)
# [Batch 0978] 未检测到火焰或烟雾 (0.04s)
# [Batch 0979] 未检测到火焰或烟雾 (0.04s)
# [Batch 0980] 未检测到火焰或烟雾 (0.04s)
# [Batch 0981] 未检测到火焰或烟雾 (0.04s)
# [Batch 0982] 未检测到火焰或烟雾 (0.04s)
# [Batch 0983] 未检测到火焰或烟雾 (0.04s)
# [Batch 0984] 未检测到火焰或烟雾 (0.04s)
# [Batch 0985] 未检测到火焰或烟雾 (0.04s)
# [Batch 0986] 未检测到火焰或烟雾 (0.04s)
# [Batch 0987] 未检测到火焰或烟雾 (0.04s)
# [Batch 0988] 未检测到火焰或烟雾 (0.04s)
# [Batch 0989] 未检测到火焰或烟雾 (0.04s)
# [Batch 0990] 未检测到火焰或烟雾 (0.04s)
# [Batch 0991] 未检测到火焰或烟雾 (0.04s)
# [Batch 0992] 未检测到火焰或烟雾 (0.04s)
# [Batch 0993] 未检测到火焰或烟雾 (0.04s)
# [Batch 0994] 未检测到火焰或烟雾 (0.04s)
# [Batch 0995] 未检测到火焰或烟雾 (0.04s)
# [Batch 0996] 未检测到火焰或烟雾 (0.04s)
# [Batch 0997] [警告] 发现火灾! 动态特征置信度: 0.961 (0.06s)
# [Batch 0998] 未检测到火焰或烟雾 (0.04s)
# [Batch 0999] 未检测到火焰或烟雾 (0.04s)
# [Batch 1000] 未检测到火焰或烟雾 (0.04s)
# [Batch 1001] [警告] 发现火灾! 动态特征置信度: 0.886 (0.07s)
# [Batch 1002] [警告] 发现火灾! 动态特征置信度: 0.913 (0.09s)
# [Batch 1003] [警告] 发现火灾! 动态特征置信度: 0.915 (0.11s)
# [Batch 1004] 未发现火灾，疑似静态图片 (静态置信度: 0.892) (0.11s)
# [Batch 1005] 未发现火灾，疑似静态图片 (静态置信度: 0.789) (0.09s)
# [Batch 1006] 未检测到火焰或烟雾 (0.04s)
# [Batch 1007] 未检测到火焰或烟雾 (0.04s)
# [Batch 1008] 未检测到火焰或烟雾 (0.04s)
# [Batch 1009] 未检测到火焰或烟雾 (0.04s)
# [Batch 1010] 未检测到火焰或烟雾 (0.04s)
# [Batch 1011] 未检测到火焰或烟雾 (0.04s)
# [Batch 1012] 未检测到火焰或烟雾 (0.04s)
# [Batch 1013] [警告] 发现火灾! 动态特征置信度: 0.926 (0.09s)
# [Batch 1014] 未检测到火焰或烟雾 (0.04s)
# [Batch 1015] 未检测到火焰或烟雾 (0.04s)
# [Batch 1016] 未发现火灾，疑似静态图片 (静态置信度: 0.988) (0.07s)
# [Batch 1017] [警告] 发现火灾! 动态特征置信度: 0.954 (0.06s)
# [Batch 1018] [警告] 发现火灾! 动态特征置信度: 0.868 (0.08s)
# [Batch 1019] 未检测到火焰或烟雾 (0.04s)
# [Batch 1020] 未检测到火焰或烟雾 (0.04s)
# [Batch 1021] 未检测到火焰或烟雾 (0.04s)
# [Batch 1022] [警告] 发现火灾! 动态特征置信度: 0.939 (0.09s)
# [Batch 1023] [警告] 发现火灾! 动态特征置信度: 0.955 (0.06s)
# [Batch 1024] 未检测到火焰或烟雾 (0.04s)
# [Batch 1025] [警告] 发现火灾! 动态特征置信度: 0.918 (0.06s)
# [Batch 1026] 未检测到火焰或烟雾 (0.04s)
# [Batch 1027] [警告] 发现火灾! 动态特征置信度: 0.958 (0.08s)
# [Batch 1028] 未检测到火焰或烟雾 (0.04s)
# [Batch 1029] 未检测到火焰或烟雾 (0.04s)
# [Batch 1030] 未发现火灾，疑似静态图片 (静态置信度: 0.765) (0.07s)
# [Batch 1031] [警告] 发现火灾! 动态特征置信度: 0.952 (0.08s)
# [Batch 1032] [警告] 发现火灾! 动态特征置信度: 0.952 (0.09s)
# [Batch 1033] [警告] 发现火灾! 动态特征置信度: 0.968 (0.10s)
# [Batch 1034] 未检测到火焰或烟雾 (0.04s)
# [Batch 1035] 未发现火灾，疑似静态图片 (静态置信度: 0.610) (0.11s)
# [Batch 1036] [警告] 发现火灾! 动态特征置信度: 0.960 (0.06s)
# [Batch 1037] [警告] 发现火灾! 动态特征置信度: 0.938 (0.06s)
# [Batch 1038] [警告] 发现火灾! 动态特征置信度: 0.970 (0.09s)
# [Batch 1039] [警告] 发现火灾! 动态特征置信度: 0.973 (0.08s)
# [Batch 1040] [警告] 发现火灾! 动态特征置信度: 0.958 (0.08s)
# [Batch 1041] 未发现火灾，疑似静态图片 (静态置信度: 0.964) (0.09s)
# [Batch 1042] [警告] 发现火灾! 动态特征置信度: 0.978 (0.09s)
# [Batch 1043] 未发现火灾，疑似静态图片 (静态置信度: 0.987) (0.10s)
# [Batch 1044] 未发现火灾，疑似静态图片 (静态置信度: 0.746) (0.11s)
# [Batch 1045] 未发现火灾，疑似静态图片 (静态置信度: 0.710) (0.11s)
# [Batch 1046] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1047] [警告] 发现火灾! 动态特征置信度: 0.974 (0.09s)
# [Batch 1048] [警告] 发现火灾! 动态特征置信度: 0.941 (0.07s)
# [Batch 1049] 未检测到火焰或烟雾 (0.04s)
# [Batch 1050] 未发现火灾，疑似静态图片 (静态置信度: 0.977) (0.07s)
# [Batch 1051] [警告] 发现火灾! 动态特征置信度: 0.960 (0.07s)
# [Batch 1052] [警告] 发现火灾! 动态特征置信度: 0.920 (0.07s)
# [Batch 1053] [警告] 发现火灾! 动态特征置信度: 0.881 (0.10s)
# [Batch 1054] [警告] 发现火灾! 动态特征置信度: 0.620 (0.11s)
# [Batch 1055] [警告] 发现火灾! 动态特征置信度: 0.959 (0.11s)
# [Batch 1056] [警告] 发现火灾! 动态特征置信度: 0.978 (0.09s)
# [Batch 1057] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1058] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1059] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1060] [警告] 发现火灾! 动态特征置信度: 0.730 (0.10s)
# [Batch 1061] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1062] 未发现火灾，疑似静态图片 (静态置信度: 0.581) (0.10s)
# [Batch 1063] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1064] [警告] 发现火灾! 动态特征置信度: 0.659 (0.11s)
# [Batch 1065] [警告] 发现火灾! 动态特征置信度: 0.961 (0.10s)
# [Batch 1066] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1067] 未发现火灾，疑似静态图片 (静态置信度: 0.828) (0.11s)
# [Batch 1068] [警告] 发现火灾! 动态特征置信度: 0.913 (0.11s)
# [Batch 1069] [警告] 发现火灾! 动态特征置信度: 0.861 (0.09s)
# [Batch 1070] 未发现火灾，疑似静态图片 (静态置信度: 0.574) (0.11s)
# [Batch 1071] [警告] 发现火灾! 动态特征置信度: 0.951 (0.11s)
# [Batch 1072] [警告] 发现火灾! 动态特征置信度: 0.959 (0.10s)
# [Batch 1073] 未发现火灾，疑似静态图片 (静态置信度: 0.613) (0.11s)
# [Batch 1074] 未发现火灾，疑似静态图片 (静态置信度: 0.944) (0.11s)
# [Batch 1075] 未发现火灾，疑似静态图片 (静态置信度: 0.818) (0.10s)
# [Batch 1076] 未发现火灾，疑似静态图片 (静态置信度: 0.963) (0.11s)
# [Batch 1077] [警告] 发现火灾! 动态特征置信度: 0.947 (0.08s)
# [Batch 1078] 未发现火灾，疑似静态图片 (静态置信度: 0.979) (0.11s)
# [Batch 1079] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.09s)
# [Batch 1080] [警告] 发现火灾! 动态特征置信度: 0.968 (0.10s)
# [Batch 1081] [警告] 发现火灾! 动态特征置信度: 0.911 (0.11s)
# [Batch 1082] 未发现火灾，疑似静态图片 (静态置信度: 0.983) (0.11s)
# [Batch 1083] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1084] [警告] 发现火灾! 动态特征置信度: 0.603 (0.11s)
# [Batch 1085] [警告] 发现火灾! 动态特征置信度: 0.869 (0.11s)
# [Batch 1086] [警告] 发现火灾! 动态特征置信度: 0.875 (0.11s)
# [Batch 1087] [警告] 发现火灾! 动态特征置信度: 0.900 (0.11s)
# [Batch 1088] [警告] 发现火灾! 动态特征置信度: 0.912 (0.11s)
# [Batch 1089] [警告] 发现火灾! 动态特征置信度: 0.938 (0.11s)
# [Batch 1090] [警告] 发现火灾! 动态特征置信度: 0.939 (0.11s)
# [Batch 1091] 未发现火灾，疑似静态图片 (静态置信度: 0.684) (0.11s)
# [Batch 1092] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1093] [警告] 发现火灾! 动态特征置信度: 0.546 (0.11s)
# [Batch 1094] [警告] 发现火灾! 动态特征置信度: 0.924 (0.11s)
# [Batch 1095] [警告] 发现火灾! 动态特征置信度: 0.950 (0.11s)
# [Batch 1096] [警告] 发现火灾! 动态特征置信度: 0.743 (0.11s)
# [Batch 1097] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1098] 未发现火灾，疑似静态图片 (静态置信度: 0.526) (0.11s)
# [Batch 1099] 未发现火灾，疑似静态图片 (静态置信度: 0.914) (0.11s)
# [Batch 1100] 未发现火灾，疑似静态图片 (静态置信度: 0.974) (0.11s)
# [Batch 1101] [警告] 发现火灾! 动态特征置信度: 0.770 (0.10s)
# [Batch 1102] [警告] 发现火灾! 动态特征置信度: 0.941 (0.10s)
# [Batch 1103] 未发现火灾，疑似静态图片 (静态置信度: 0.831) (0.11s)
# [Batch 1104] [警告] 发现火灾! 动态特征置信度: 0.975 (0.11s)
# [Batch 1105] [警告] 发现火灾! 动态特征置信度: 0.975 (0.11s)
# [Batch 1106] 未发现火灾，疑似静态图片 (静态置信度: 0.875) (0.11s)
# [Batch 1107] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1108] 未发现火灾，疑似静态图片 (静态置信度: 0.933) (0.11s)
# [Batch 1109] [警告] 发现火灾! 动态特征置信度: 0.905 (0.08s)
# [Batch 1110] 未发现火灾，疑似静态图片 (静态置信度: 0.986) (0.11s)
# [Batch 1111] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1112] 未发现火灾，疑似静态图片 (静态置信度: 0.981) (0.11s)
# [Batch 1113] 未发现火灾，疑似静态图片 (静态置信度: 0.891) (0.11s)
# [Batch 1114] [警告] 发现火灾! 动态特征置信度: 0.905 (0.12s)
# [Batch 1115] [警告] 发现火灾! 动态特征置信度: 0.918 (0.12s)
# [Batch 1116] [警告] 发现火灾! 动态特征置信度: 0.967 (0.11s)
# [Batch 1117] [警告] 发现火灾! 动态特征置信度: 0.698 (0.11s)
# [Batch 1118] [警告] 发现火灾! 动态特征置信度: 0.908 (0.11s)
# [Batch 1119] [警告] 发现火灾! 动态特征置信度: 0.936 (0.11s)
# [Batch 1120] [警告] 发现火灾! 动态特征置信度: 0.963 (0.10s)
# [Batch 1121] 未发现火灾，疑似静态图片 (静态置信度: 0.760) (0.11s)
# [Batch 1122] [警告] 发现火灾! 动态特征置信度: 0.917 (0.11s)
# [Batch 1123] 未发现火灾，疑似静态图片 (静态置信度: 0.988) (0.11s)
# [Batch 1124] [警告] 发现火灾! 动态特征置信度: 0.889 (0.11s)
# [Batch 1125] 未发现火灾，疑似静态图片 (静态置信度: 0.597) (0.11s)
# [Batch 1126] 未发现火灾，疑似静态图片 (静态置信度: 0.872) (0.11s)
# [Batch 1127] 未发现火灾，疑似静态图片 (静态置信度: 0.963) (0.11s)
# [Batch 1128] [警告] 发现火灾! 动态特征置信度: 0.898 (0.12s)
# [Batch 1129] [警告] 发现火灾! 动态特征置信度: 0.977 (0.11s)
# [Batch 1130] 未发现火灾，疑似静态图片 (静态置信度: 0.607) (0.12s)
# [Batch 1131] 未发现火灾，疑似静态图片 (静态置信度: 0.847) (0.11s)
# [Batch 1132] [警告] 发现火灾! 动态特征置信度: 0.913 (0.11s)
# [Batch 1133] [警告] 发现火灾! 动态特征置信度: 0.935 (0.11s)
# [Batch 1134] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1135] 未发现火灾，疑似静态图片 (静态置信度: 0.988) (0.11s)
# [Batch 1136] 未发现火灾，疑似静态图片 (静态置信度: 0.626) (0.11s)
# [Batch 1137] 未发现火灾，疑似静态图片 (静态置信度: 0.985) (0.12s)
# [Batch 1138] 未发现火灾，疑似静态图片 (静态置信度: 0.979) (0.11s)
# [Batch 1139] 未发现火灾，疑似静态图片 (静态置信度: 0.961) (0.11s)
# [Batch 1140] 未发现火灾，疑似静态图片 (静态置信度: 0.507) (0.11s)
# [Batch 1141] 未发现火灾，疑似静态图片 (静态置信度: 0.621) (0.11s)
# [Batch 1142] 未发现火灾，疑似静态图片 (静态置信度: 0.986) (0.11s)
# [Batch 1143] 未发现火灾，疑似静态图片 (静态置信度: 0.972) (0.11s)
# [Batch 1144] [警告] 发现火灾! 动态特征置信度: 0.945 (0.11s)
# [Batch 1145] 未发现火灾，疑似静态图片 (静态置信度: 0.973) (0.11s)
# [Batch 1146] [警告] 发现火灾! 动态特征置信度: 0.933 (0.11s)
# [Batch 1147] 未发现火灾，疑似静态图片 (静态置信度: 0.977) (0.11s)
# [Batch 1148] [警告] 发现火灾! 动态特征置信度: 0.901 (0.11s)
# [Batch 1149] 未发现火灾，疑似静态图片 (静态置信度: 0.920) (0.12s)
# [Batch 1150] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1151] [警告] 发现火灾! 动态特征置信度: 0.917 (0.11s)
# [Batch 1152] 未发现火灾，疑似静态图片 (静态置信度: 0.974) (0.11s)
# [Batch 1153] [警告] 发现火灾! 动态特征置信度: 0.939 (0.11s)
# [Batch 1154] 未发现火灾，疑似静态图片 (静态置信度: 0.706) (0.11s)
# [Batch 1155] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.12s)
# [Batch 1156] 未发现火灾，疑似静态图片 (静态置信度: 0.882) (0.11s)
# [Batch 1157] [警告] 发现火灾! 动态特征置信度: 0.551 (0.11s)
# [Batch 1158] [警告] 发现火灾! 动态特征置信度: 0.602 (0.11s)
# [Batch 1159] [警告] 发现火灾! 动态特征置信度: 0.934 (0.12s)
# [Batch 1160] 未发现火灾，疑似静态图片 (静态置信度: 0.748) (0.11s)
# [Batch 1161] 未发现火灾，疑似静态图片 (静态置信度: 0.945) (0.11s)
# [Batch 1162] [警告] 发现火灾! 动态特征置信度: 0.952 (0.11s)
# [Batch 1163] [警告] 发现火灾! 动态特征置信度: 0.971 (0.10s)
# [Batch 1164] [警告] 发现火灾! 动态特征置信度: 0.880 (0.11s)
# [Batch 1165] 未发现火灾，疑似静态图片 (静态置信度: 0.920) (0.12s)
# [Batch 1166] [警告] 发现火灾! 动态特征置信度: 0.939 (0.10s)
# [Batch 1167] 未发现火灾，疑似静态图片 (静态置信度: 0.973) (0.12s)
# [Batch 1168] [警告] 发现火灾! 动态特征置信度: 0.947 (0.11s)
# [Batch 1169] [警告] 发现火灾! 动态特征置信度: 0.927 (0.11s)
# [Batch 1170] 未发现火灾，疑似静态图片 (静态置信度: 0.943) (0.11s)
# [Batch 1171] [警告] 发现火灾! 动态特征置信度: 0.854 (0.11s)
# [Batch 1172] [警告] 发现火灾! 动态特征置信度: 0.954 (0.10s)
# [Batch 1173] [警告] 发现火灾! 动态特征置信度: 0.990 (0.10s)
# [Batch 1174] 未发现火灾，疑似静态图片 (静态置信度: 0.980) (0.11s)
# [Batch 1175] 未发现火灾，疑似静态图片 (静态置信度: 0.880) (0.10s)
# [Batch 1176] 未发现火灾，疑似静态图片 (静态置信度: 0.601) (0.11s)
# [Batch 1177] [警告] 发现火灾! 动态特征置信度: 0.728 (0.11s)
# [Batch 1178] [警告] 发现火灾! 动态特征置信度: 0.982 (0.10s)
# [Batch 1179] [警告] 发现火灾! 动态特征置信度: 0.978 (0.10s)
# [Batch 1180] [警告] 发现火灾! 动态特征置信度: 0.705 (0.11s)
# [Batch 1181] 未发现火灾，疑似静态图片 (静态置信度: 0.808) (0.11s)
# [Batch 1182] [警告] 发现火灾! 动态特征置信度: 0.973 (0.11s)
# [Batch 1183] [警告] 发现火灾! 动态特征置信度: 0.844 (0.11s)
# [Batch 1184] 未发现火灾，疑似静态图片 (静态置信度: 0.985) (0.11s)
# [Batch 1185] 未发现火灾，疑似静态图片 (静态置信度: 0.950) (0.11s)
# [Batch 1186] [警告] 发现火灾! 动态特征置信度: 0.991 (0.11s)
# [Batch 1187] 未发现火灾，疑似静态图片 (静态置信度: 0.910) (0.11s)
# [Batch 1188] [警告] 发现火灾! 动态特征置信度: 0.977 (0.11s)
# [Batch 1189] [警告] 发现火灾! 动态特征置信度: 0.915 (0.11s)
# [Batch 1190] 未发现火灾，疑似静态图片 (静态置信度: 0.829) (0.11s)
# [Batch 1191] [警告] 发现火灾! 动态特征置信度: 0.928 (0.10s)
# [Batch 1192] [警告] 发现火灾! 动态特征置信度: 0.947 (0.09s)
# [Batch 1193] [警告] 发现火灾! 动态特征置信度: 0.995 (0.09s)
# [Batch 1194] [警告] 发现火灾! 动态特征置信度: 0.985 (0.08s)
# [Batch 1195] [警告] 发现火灾! 动态特征置信度: 0.986 (0.09s)
# [Batch 1196] [警告] 发现火灾! 动态特征置信度: 0.995 (0.08s)
# [Batch 1197] 未发现火灾，疑似静态图片 (静态置信度: 0.510) (0.11s)
# [Batch 1198] [警告] 发现火灾! 动态特征置信度: 0.938 (0.11s)
# [Batch 1199] [警告] 发现火灾! 动态特征置信度: 0.978 (0.11s)
# [Batch 1200] [警告] 发现火灾! 动态特征置信度: 0.990 (0.10s)
# [Batch 1201] [警告] 发现火灾! 动态特征置信度: 0.955 (0.09s)
# [Batch 1202] 未发现火灾，疑似静态图片 (静态置信度: 0.861) (0.11s)
# [Batch 1203] [警告] 发现火灾! 动态特征置信度: 0.967 (0.10s)
# [Batch 1204] [警告] 发现火灾! 动态特征置信度: 0.980 (0.09s)
# [Batch 1205] [警告] 发现火灾! 动态特征置信度: 0.986 (0.11s)
# [Batch 1206] [警告] 发现火灾! 动态特征置信度: 0.973 (0.11s)
# [Batch 1207] [警告] 发现火灾! 动态特征置信度: 0.991 (0.08s)
# [Batch 1208] [警告] 发现火灾! 动态特征置信度: 0.980 (0.08s)
# [Batch 1209] [警告] 发现火灾! 动态特征置信度: 0.938 (0.07s)
# [Batch 1210] [警告] 发现火灾! 动态特征置信度: 0.982 (0.09s)
# [Batch 1211] [警告] 发现火灾! 动态特征置信度: 0.982 (0.08s)
# [Batch 1212] [警告] 发现火灾! 动态特征置信度: 0.966 (0.08s)
# [Batch 1213] [警告] 发现火灾! 动态特征置信度: 0.993 (0.10s)
# [Batch 1214] [警告] 发现火灾! 动态特征置信度: 0.961 (0.09s)
# [Batch 1215] [警告] 发现火灾! 动态特征置信度: 0.929 (0.11s)
# [Batch 1216] [警告] 发现火灾! 动态特征置信度: 0.982 (0.10s)
# [Batch 1217] [警告] 发现火灾! 动态特征置信度: 0.969 (0.09s)
# [Batch 1218] [警告] 发现火灾! 动态特征置信度: 0.992 (0.07s)
# [Batch 1219] [警告] 发现火灾! 动态特征置信度: 0.963 (0.07s)
# [Batch 1220] [警告] 发现火灾! 动态特征置信度: 0.975 (0.11s)
# [Batch 1221] [警告] 发现火灾! 动态特征置信度: 0.980 (0.09s)
# [Batch 1222] [警告] 发现火灾! 动态特征置信度: 0.994 (0.09s)
# [Batch 1223] [警告] 发现火灾! 动态特征置信度: 0.987 (0.08s)
# [Batch 1224] [警告] 发现火灾! 动态特征置信度: 0.956 (0.08s)
# [Batch 1225] [警告] 发现火灾! 动态特征置信度: 0.943 (0.08s)
# [Batch 1226] [警告] 发现火灾! 动态特征置信度: 0.997 (0.08s)
# [Batch 1227] [警告] 发现火灾! 动态特征置信度: 0.996 (0.08s)
# [Batch 1228] [警告] 发现火灾! 动态特征置信度: 0.965 (0.10s)
# [Batch 1229] [警告] 发现火灾! 动态特征置信度: 0.962 (0.09s)
# [Batch 1230] [警告] 发现火灾! 动态特征置信度: 0.987 (0.08s)
# [Batch 1231] [警告] 发现火灾! 动态特征置信度: 0.969 (0.09s)
# [Batch 1232] [警告] 发现火灾! 动态特征置信度: 0.963 (0.08s)
# [Batch 1233] [警告] 发现火灾! 动态特征置信度: 0.967 (0.11s)
# [Batch 1234] [警告] 发现火灾! 动态特征置信度: 0.964 (0.09s)
# [Batch 1235] [警告] 发现火灾! 动态特征置信度: 0.888 (0.12s)
# [Batch 1236] [警告] 发现火灾! 动态特征置信度: 0.884 (0.10s)
# [Batch 1237] [警告] 发现火灾! 动态特征置信度: 0.981 (0.10s)
# [Batch 1238] 未发现火灾，疑似静态图片 (静态置信度: 0.988) (0.11s)
# [Batch 1239] [警告] 发现火灾! 动态特征置信度: 0.977 (0.10s)
# [Batch 1240] 未发现火灾，疑似静态图片 (静态置信度: 0.987) (0.11s)
# [Batch 1241] [警告] 发现火灾! 动态特征置信度: 0.974 (0.11s)
# [Batch 1242] [警告] 发现火灾! 动态特征置信度: 0.892 (0.11s)
# [Batch 1243] 未发现火灾，疑似静态图片 (静态置信度: 0.807) (0.11s)
# [Batch 1244] [警告] 发现火灾! 动态特征置信度: 0.912 (0.11s)
# [Batch 1245] [警告] 发现火灾! 动态特征置信度: 0.977 (0.11s)
# [Batch 1246] [警告] 发现火灾! 动态特征置信度: 0.995 (0.10s)
# [Batch 1247] [警告] 发现火灾! 动态特征置信度: 0.976 (0.08s)
# [Batch 1248] [警告] 发现火灾! 动态特征置信度: 0.971 (0.10s)
# [Batch 1249] [警告] 发现火灾! 动态特征置信度: 0.983 (0.09s)
# [Batch 1250] [警告] 发现火灾! 动态特征置信度: 0.954 (0.10s)
# [Batch 1251] [警告] 发现火灾! 动态特征置信度: 0.988 (0.10s)
# [Batch 1252] [警告] 发现火灾! 动态特征置信度: 0.981 (0.08s)
# [Batch 1253] [警告] 发现火灾! 动态特征置信度: 0.965 (0.08s)
# [Batch 1254] [警告] 发现火灾! 动态特征置信度: 0.982 (0.08s)
# [Batch 1255] [警告] 发现火灾! 动态特征置信度: 0.986 (0.10s)
# [Batch 1256] [警告] 发现火灾! 动态特征置信度: 0.965 (0.09s)
# [Batch 1257] [警告] 发现火灾! 动态特征置信度: 0.992 (0.06s)
# [Batch 1258] [警告] 发现火灾! 动态特征置信度: 0.997 (0.08s)
# [Batch 1259] [警告] 发现火灾! 动态特征置信度: 0.993 (0.07s)
# [Batch 1260] [警告] 发现火灾! 动态特征置信度: 0.947 (0.11s)
# [Batch 1261] [警告] 发现火灾! 动态特征置信度: 0.936 (0.11s)
# [Batch 1262] 未发现火灾，疑似静态图片 (静态置信度: 0.906) (0.11s)
# [Batch 1263] [警告] 发现火灾! 动态特征置信度: 0.977 (0.11s)
# [Batch 1264] [警告] 发现火灾! 动态特征置信度: 0.985 (0.08s)
# [Batch 1265] [警告] 发现火灾! 动态特征置信度: 0.976 (0.09s)
# [Batch 1266] [警告] 发现火灾! 动态特征置信度: 0.986 (0.10s)
# [Batch 1267] [警告] 发现火灾! 动态特征置信度: 0.963 (0.11s)
# [Batch 1268] [警告] 发现火灾! 动态特征置信度: 0.965 (0.11s)
# [Batch 1269] [警告] 发现火灾! 动态特征置信度: 0.926 (0.11s)
# [Batch 1270] [警告] 发现火灾! 动态特征置信度: 0.972 (0.10s)
# [Batch 1271] 未发现火灾，疑似静态图片 (静态置信度: 0.856) (0.11s)
# [Batch 1272] [警告] 发现火灾! 动态特征置信度: 0.952 (0.11s)
# [Batch 1273] [警告] 发现火灾! 动态特征置信度: 0.975 (0.10s)
# [Batch 1274] [警告] 发现火灾! 动态特征置信度: 0.978 (0.11s)
# [Batch 1275] [警告] 发现火灾! 动态特征置信度: 0.979 (0.11s)
# [Batch 1276] [警告] 发现火灾! 动态特征置信度: 0.976 (0.11s)
# [Batch 1277] [警告] 发现火灾! 动态特征置信度: 0.979 (0.11s)
# [Batch 1278] 未发现火灾，疑似静态图片 (静态置信度: 0.915) (0.11s)
# [Batch 1279] [警告] 发现火灾! 动态特征置信度: 0.959 (0.11s)
# [Batch 1280] [警告] 发现火灾! 动态特征置信度: 0.950 (0.11s)
# [Batch 1281] [警告] 发现火灾! 动态特征置信度: 0.988 (0.11s)
# [Batch 1282] [警告] 发现火灾! 动态特征置信度: 0.951 (0.11s)
# [Batch 1283] [警告] 发现火灾! 动态特征置信度: 0.946 (0.11s)
# [Batch 1284] [警告] 发现火灾! 动态特征置信度: 0.751 (0.11s)
# [Batch 1285] 未发现火灾，疑似静态图片 (静态置信度: 0.989) (0.11s)
# [Batch 1286] [警告] 发现火灾! 动态特征置信度: 0.923 (0.11s)
# [Batch 1287] [警告] 发现火灾! 动态特征置信度: 0.776 (0.11s)
# [Batch 1288] 未发现火灾，疑似静态图片 (静态置信度: 0.755) (0.11s)
# [Batch 1289] 未发现火灾，疑似静态图片 (静态置信度: 0.807) (0.11s)
# [Batch 1290] 未发现火灾，疑似静态图片 (静态置信度: 0.768) (0.11s)
# [Batch 1291] [警告] 发现火灾! 动态特征置信度: 0.952 (0.09s)
# [Batch 1292] [警告] 发现火灾! 动态特征置信度: 0.962 (0.09s)
# [Batch 1293] [警告] 发现火灾! 动态特征置信度: 0.985 (0.09s)
# [Batch 1294] [警告] 发现火灾! 动态特征置信度: 0.978 (0.10s)
# [Batch 1295] [警告] 发现火灾! 动态特征置信度: 0.978 (0.11s)
# [Batch 1296] [警告] 发现火灾! 动态特征置信度: 0.980 (0.10s)
# [Batch 1297] 未发现火灾，疑似静态图片 (静态置信度: 0.945) (0.11s)
# [Batch 1298] [警告] 发现火灾! 动态特征置信度: 0.968 (0.10s)
# [Batch 1299] [警告] 发现火灾! 动态特征置信度: 0.970 (0.10s)
# [Batch 1300] [警告] 发现火灾! 动态特征置信度: 0.983 (0.09s)
# [Batch 1301] [警告] 发现火灾! 动态特征置信度: 0.977 (0.11s)
# [Batch 1302] [警告] 发现火灾! 动态特征置信度: 0.975 (0.10s)
# [Batch 1303] [警告] 发现火灾! 动态特征置信度: 0.947 (0.11s)
# [Batch 1304] [警告] 发现火灾! 动态特征置信度: 0.989 (0.10s)
# [Batch 1305] [警告] 发现火灾! 动态特征置信度: 0.963 (0.11s)
# [Batch 1306] [警告] 发现火灾! 动态特征置信度: 0.924 (0.11s)
# [Batch 1307] [警告] 发现火灾! 动态特征置信度: 0.911 (0.11s)
# [Batch 1308] [警告] 发现火灾! 动态特征置信度: 0.961 (0.11s)
# [Batch 1309] [警告] 发现火灾! 动态特征置信度: 0.937 (0.11s)
# [Batch 1310] [警告] 发现火灾! 动态特征置信度: 0.970 (0.11s)
# [Batch 1311] [警告] 发现火灾! 动态特征置信度: 0.855 (0.12s)
# [Batch 1312] [警告] 发现火灾! 动态特征置信度: 0.976 (0.11s)
# [Batch 1313] [警告] 发现火灾! 动态特征置信度: 0.973 (0.11s)
# [Batch 1314] 未发现火灾，疑似静态图片 (静态置信度: 0.963) (0.11s)
# [Batch 1315] [警告] 发现火灾! 动态特征置信度: 0.962 (0.11s)
# [Batch 1316] [警告] 发现火灾! 动态特征置信度: 0.961 (0.11s)
# [Batch 1317] [警告] 发现火灾! 动态特征置信度: 0.961 (0.11s)
# [Batch 1318] [警告] 发现火灾! 动态特征置信度: 0.954 (0.11s)
# [Batch 1319] [警告] 发现火灾! 动态特征置信度: 0.702 (0.11s)
# [Batch 1320] [警告] 发现火灾! 动态特征置信度: 0.977 (0.11s)
# [Batch 1321] [警告] 发现火灾! 动态特征置信度: 0.931 (0.11s)
# [Batch 1322] [警告] 发现火灾! 动态特征置信度: 0.985 (0.10s)
# [Batch 1323] [警告] 发现火灾! 动态特征置信度: 0.951 (0.10s)
# [Batch 1324] [警告] 发现火灾! 动态特征置信度: 0.961 (0.11s)
# [Batch 1325] [警告] 发现火灾! 动态特征置信度: 0.835 (0.12s)
# [Batch 1326] [警告] 发现火灾! 动态特征置信度: 0.958 (0.11s)
# [Batch 1327] [警告] 发现火灾! 动态特征置信度: 0.960 (0.10s)
# [Batch 1328] [警告] 发现火灾! 动态特征置信度: 0.948 (0.10s)
# [Batch 1329] [警告] 发现火灾! 动态特征置信度: 0.983 (0.11s)
# [Batch 1330] [警告] 发现火灾! 动态特征置信度: 0.992 (0.10s)
# [Batch 1331] [警告] 发现火灾! 动态特征置信度: 0.973 (0.11s)
# [Batch 1332] [警告] 发现火灾! 动态特征置信度: 0.961 (0.11s)
# [Batch 1333] [警告] 发现火灾! 动态特征置信度: 0.959 (0.11s)
# [Batch 1334] [警告] 发现火灾! 动态特征置信度: 0.980 (0.10s)
# [Batch 1335] [警告] 发现火灾! 动态特征置信度: 0.899 (0.11s)
# [Batch 1336] [警告] 发现火灾! 动态特征置信度: 0.967 (0.12s)
# [Batch 1337] [警告] 发现火灾! 动态特征置信度: 0.871 (0.11s)
# [Batch 1338] [警告] 发现火灾! 动态特征置信度: 0.755 (0.11s)
# [Batch 1339] [警告] 发现火灾! 动态特征置信度: 0.824 (0.11s)
# [Batch 1340] [警告] 发现火灾! 动态特征置信度: 0.957 (0.12s)
# [Batch 1341] [警告] 发现火灾! 动态特征置信度: 0.838 (0.11s)
# [Batch 1342] [警告] 发现火灾! 动态特征置信度: 0.600 (0.11s)
# [Batch 1343] [警告] 发现火灾! 动态特征置信度: 0.972 (0.11s)
# [Batch 1344] [警告] 发现火灾! 动态特征置信度: 0.958 (0.11s)
# [Batch 1345] [警告] 发现火灾! 动态特征置信度: 0.972 (0.11s)
# [Batch 1346] [警告] 发现火灾! 动态特征置信度: 0.979 (0.11s)
# [Batch 1347] [警告] 发现火灾! 动态特征置信度: 0.930 (0.11s)
# ...
# [Batch 3334] 未检测到火焰或烟雾 (0.04s)
# [Batch 3335] 未检测到火焰或烟雾 (0.04s)
# [Batch 3336] 未检测到火焰或烟雾 (0.04s)
# [Batch 3337] 未检测到火焰或烟雾 (0.04s)
# [Batch 3338] 未检测到火焰或烟雾 (0.04s)
# [Batch 3339] 未检测到火焰或烟雾 (0.04s)
# [Batch 3340] 未检测到火焰或烟雾 (0.04s)
# [Batch 3341] 未检测到火焰或烟雾 (0.04s)
# [Batch 3342] 未检测到火焰或烟雾 (0.04s)
# [Batch 3343] 未检测到火焰或烟雾 (0.04s)
# [Batch 3344] 未检测到火焰或烟雾 (0.04s)
# [Batch 3345] 未检测到火焰或烟雾 (0.04s)
# [Batch 3346] 未检测到火焰或烟雾 (0.04s)
# [Batch 3347] 未检测到火焰或烟雾 (0.04s)
# [Batch 3348] 未检测到火焰或烟雾 (0.04s)
# [Batch 3349] 未检测到火焰或烟雾 (0.04s)
# [Batch 3350] 未检测到火焰或烟雾 (0.04s)
# [Batch 3351] 未检测到火焰或烟雾 (0.04s)
# [Batch 3352] 未检测到火焰或烟雾 (0.04s)
# [Batch 3353] 未检测到火焰或烟雾 (0.04s)
# [Batch 3354] 未检测到火焰或烟雾 (0.04s)
# [Batch 3355] 未检测到火焰或烟雾 (0.04s)
# [Batch 3356] 未检测到火焰或烟雾 (0.05s)
# [Batch 3357] 未检测到火焰或烟雾 (0.04s)
# [Batch 3358] 未检测到火焰或烟雾 (0.04s)
# [Batch 3359] 未检测到火焰或烟雾 (0.04s)
# [Batch 3360] 未检测到火焰或烟雾 (0.04s)
# [Batch 3361] 未检测到火焰或烟雾 (0.04s)
# [Batch 3362] 未检测到火焰或烟雾 (0.04s)
# [Batch 3363] 未检测到火焰或烟雾 (0.04s)
# [Batch 3364] 未检测到火焰或烟雾 (0.04s)
# [Batch 3365] 未检测到火焰或烟雾 (0.04s)
# [Batch 3366] 未检测到火焰或烟雾 (0.04s)
# [Batch 3367] 未检测到火焰或烟雾 (0.04s)
# [Batch 3368] 未检测到火焰或烟雾 (0.04s)
# [Batch 3369] 未检测到火焰或烟雾 (0.04s)
# [Batch 3370] 未检测到火焰或烟雾 (0.04s)
# [Batch 3371] 未检测到火焰或烟雾 (0.04s)
# [Batch 3372] 未检测到火焰或烟雾 (0.04s)
# [Batch 3373] 未检测到火焰或烟雾 (0.04s)
# [Batch 3374] 未检测到火焰或烟雾 (0.04s)
# [Batch 3375] 未检测到火焰或烟雾 (0.04s)
# [Batch 3376] 未检测到火焰或烟雾 (0.04s)
# [Batch 3377] 未检测到火焰或烟雾 (0.04s)
# [Batch 3378] 未检测到火焰或烟雾 (0.04s)
# [Batch 3379] 未检测到火焰或烟雾 (0.04s)
# [Batch 3380] 未检测到火焰或烟雾 (0.04s)
# [Batch 3381] 未检测到火焰或烟雾 (0.04s)
# [Batch 3382] 未检测到火焰或烟雾 (0.04s)
# [Batch 3383] 未检测到火焰或烟雾 (0.04s)
# [Batch 3384] 未检测到火焰或烟雾 (0.04s)
# [Batch 3385] 未检测到火焰或烟雾 (0.04s)
# [Batch 3386] 未检测到火焰或烟雾 (0.04s)
# [Batch 3387] 未检测到火焰或烟雾 (0.04s)
# [Batch 3388] 未检测到火焰或烟雾 (0.04s)
# [Batch 3389] 未检测到火焰或烟雾 (0.04s)
# [Batch 3390] 未检测到火焰或烟雾 (0.04s)
# [Batch 3391] 未检测到火焰或烟雾 (0.04s)
# [Batch 3392] 未检测到火焰或烟雾 (0.04s)
# [Batch 3393] 未检测到火焰或烟雾 (0.04s)
# [Batch 3394] 未检测到火焰或烟雾 (0.04s)
# [Batch 3395] 未检测到火焰或烟雾 (0.04s)
# [Batch 3396] 未检测到火焰或烟雾 (0.04s)
# [Batch 3397] 未检测到火焰或烟雾 (0.04s)
# [Batch 3398] 未检测到火焰或烟雾 (0.04s)
# [Batch 3399] 未检测到火焰或烟雾 (0.04s)
# [Batch 3400] 未检测到火焰或烟雾 (0.04s)
# [Batch 3401] 未检测到火焰或烟雾 (0.04s)
# [Batch 3402] 未检测到火焰或烟雾 (0.04s)
# [Batch 3403] 未检测到火焰或烟雾 (0.04s)
# [Batch 3404] 未检测到火焰或烟雾 (0.04s)
# [Batch 3405] 未检测到火焰或烟雾 (0.04s)
# [Batch 3406] 未检测到火焰或烟雾 (0.04s)
# [Batch 3407] 未检测到火焰或烟雾 (0.04s)
# [Batch 3408] 未检测到火焰或烟雾 (0.04s)
# [Batch 3409] 未检测到火焰或烟雾 (0.04s)
# [Batch 3410] 未检测到火焰或烟雾 (0.04s)
# [Batch 3411] 未检测到火焰或烟雾 (0.04s)
# [Batch 3412] 未检测到火焰或烟雾 (0.04s)
# [Batch 3413] 未检测到火焰或烟雾 (0.04s)
# [Batch 3414] 未检测到火焰或烟雾 (0.04s)
# [Batch 3415] 未检测到火焰或烟雾 (0.04s)
# [Batch 3416] 未检测到火焰或烟雾 (0.04s)
# [Batch 3417] 未检测到火焰或烟雾 (0.04s)
# [Batch 3418] 未检测到火焰或烟雾 (0.04s)
# [Batch 3419] 未检测到火焰或烟雾 (0.04s)
# [Batch 3420] 未检测到火焰或烟雾 (0.04s)
# [Batch 3421] 未检测到火焰或烟雾 (0.04s)
# [Batch 3422] 未检测到火焰或烟雾 (0.04s)
# [Batch 3423] 未检测到火焰或烟雾 (0.04s)
# [Batch 3424] 未检测到火焰或烟雾 (0.04s)
# [Batch 3425] 未检测到火焰或烟雾 (0.04s)
# [Batch 3426] 未检测到火焰或烟雾 (0.04s)
# [Batch 3427] 未检测到火焰或烟雾 (0.04s)
# [Batch 3428] 未检测到火焰或烟雾 (0.04s)
# [Batch 3429] 未检测到火焰或烟雾 (0.04s)
# [Batch 3430] 未检测到火焰或烟雾 (0.04s)
# [Batch 3431] 未检测到火焰或烟雾 (0.04s)
# [Batch 3432] 未检测到火焰或烟雾 (0.04s)
# [Batch 3433] 未检测到火焰或烟雾 (0.04s)
# [Batch 3434] 未检测到火焰或烟雾 (0.04s)
# [Batch 3435] 未检测到火焰或烟雾 (0.04s)
# [Batch 3436] 未检测到火焰或烟雾 (0.04s)
# [Batch 3437] 未检测到火焰或烟雾 (0.04s)
# [Batch 3438] 未检测到火焰或烟雾 (0.04s)
# [Batch 3439] 未检测到火焰或烟雾 (0.04s)
# [Batch 3440] 未检测到火焰或烟雾 (0.04s)
# [Batch 3441] 未检测到火焰或烟雾 (0.04s)
# [Batch 3442] 未检测到火焰或烟雾 (0.04s)
# [Batch 3443] 未检测到火焰或烟雾 (0.04s)
# [Batch 3444] 未检测到火焰或烟雾 (0.04s)
# [Batch 3445] 未检测到火焰或烟雾 (0.04s)
# [Batch 3446] 未检测到火焰或烟雾 (0.04s)
# [Batch 3447] 未检测到火焰或烟雾 (0.04s)
# [Batch 3448] 未检测到火焰或烟雾 (0.04s)
# [Batch 3449] 未检测到火焰或烟雾 (0.04s)
# [Batch 3450] 未检测到火焰或烟雾 (0.04s)
# [Batch 3451] 未检测到火焰或烟雾 (0.04s)
# [Batch 3452] 未检测到火焰或烟雾 (0.04s)
# [Batch 3453] 未检测到火焰或烟雾 (0.04s)
# [Batch 3454] 未检测到火焰或烟雾 (0.04s)
# [Batch 3455] 未检测到火焰或烟雾 (0.04s)
# [Batch 3456] 未检测到火焰或烟雾 (0.04s)
# [Batch 3457] 未检测到火焰或烟雾 (0.04s)
# [Batch 3458] 未检测到火焰或烟雾 (0.04s)
# [Batch 3459] 未检测到火焰或烟雾 (0.04s)
# [Batch 3460] 未检测到火焰或烟雾 (0.04s)
# [Batch 3461] 未检测到火焰或烟雾 (0.04s)
# [Batch 3462] 未检测到火焰或烟雾 (0.04s)
# [Batch 3463] 未检测到火焰或烟雾 (0.04s)
# [Batch 3464] 未检测到火焰或烟雾 (0.04s)
# [Batch 3465] 未检测到火焰或烟雾 (0.04s)
# [Batch 3466] 未检测到火焰或烟雾 (0.04s)
# [Batch 3467] 未检测到火焰或烟雾 (0.04s)
# [Batch 3468] 未检测到火焰或烟雾 (0.04s)
# [Batch 3469] 未检测到火焰或烟雾 (0.04s)
# [Batch 3470] 未检测到火焰或烟雾 (0.04s)
# [Batch 3471] 未检测到火焰或烟雾 (0.04s)
# [Batch 3472] 未检测到火焰或烟雾 (0.04s)
# [Batch 3473] 未检测到火焰或烟雾 (0.04s)
# [Batch 3474] 未检测到火焰或烟雾 (0.04s)
# [Batch 3475] 未检测到火焰或烟雾 (0.04s)
# [Batch 3476] 未检测到火焰或烟雾 (0.04s)
# [Batch 3477] 未检测到火焰或烟雾 (0.04s)
# [Batch 3478] 未检测到火焰或烟雾 (0.04s)
# [Batch 3479] 未检测到火焰或烟雾 (0.04s)
# [Batch 3480] 未检测到火焰或烟雾 (0.04s)
# [Batch 3481] 未检测到火焰或烟雾 (0.04s)
# [Batch 3482] 未检测到火焰或烟雾 (0.04s)
# [Batch 3483] 未检测到火焰或烟雾 (0.04s)
# [Batch 3484] 未检测到火焰或烟雾 (0.04s)
# [Batch 3485] 未检测到火焰或烟雾 (0.04s)
# [Batch 3486] 未检测到火焰或烟雾 (0.04s)
# [Batch 3487] 未检测到火焰或烟雾 (0.04s)
# [Batch 3488] 未检测到火焰或烟雾 (0.04s)
# [Batch 3489] 未检测到火焰或烟雾 (0.04s)
# [Batch 3490] 未检测到火焰或烟雾 (0.04s)
# [Batch 3491] 未检测到火焰或烟雾 (0.04s)
# [Batch 3492] 未检测到火焰或烟雾 (0.04s)
# [Batch 3493] 未检测到火焰或烟雾 (0.04s)
# [Batch 3494] 未检测到火焰或烟雾 (0.04s)
# [Batch 3495] 未检测到火焰或烟雾 (0.04s)
# [Batch 3496] 未检测到火焰或烟雾 (0.04s)
# [Batch 3497] 未检测到火焰或烟雾 (0.04s)
# [Batch 3498] 未检测到火焰或烟雾 (0.04s)
# [Batch 3499] 未检测到火焰或烟雾 (0.04s)
# [Batch 3500] 未检测到火焰或烟雾 (0.04s)
# [Batch 3501] 未检测到火焰或烟雾 (0.04s)
# [Batch 3502] 未检测到火焰或烟雾 (0.04s)
# [Batch 3503] 未检测到火焰或烟雾 (0.04s)
# [Batch 3504] 未检测到火焰或烟雾 (0.04s)
# [Batch 3505] 未检测到火焰或烟雾 (0.04s)
# [Batch 3506] 未检测到火焰或烟雾 (0.04s)
# [Batch 3507] 未检测到火焰或烟雾 (0.04s)
# [Batch 3508] 未检测到火焰或烟雾 (0.04s)
# [Batch 3509] 未检测到火焰或烟雾 (0.04s)
# [Batch 3510] 未检测到火焰或烟雾 (0.04s)
# [Batch 3511] 未检测到火焰或烟雾 (0.04s)
# [Batch 3512] 未检测到火焰或烟雾 (0.04s)
# [Batch 3513] 未检测到火焰或烟雾 (0.04s)
# [Batch 3514] 未检测到火焰或烟雾 (0.04s)
# [Batch 3515] 未检测到火焰或烟雾 (0.04s)
# [Batch 3516] 未检测到火焰或烟雾 (0.04s)
# [Batch 3517] 未检测到火焰或烟雾 (0.04s)
# [Batch 3518] 未检测到火焰或烟雾 (0.04s)
# [Batch 3519] 未检测到火焰或烟雾 (0.04s)
# [Batch 3520] 未检测到火焰或烟雾 (0.04s)
# [Batch 3521] 未检测到火焰或烟雾 (0.04s)
# [Batch 3522] 未检测到火焰或烟雾 (0.04s)
# [Batch 3523] 未检测到火焰或烟雾 (0.04s)
# [Batch 3524] 未检测到火焰或烟雾 (0.04s)
# [Batch 3525] 未检测到火焰或烟雾 (0.04s)
# [Batch 3526] 未检测到火焰或烟雾 (0.04s)
# [Batch 3527] 未检测到火焰或烟雾 (0.04s)
# [Batch 3528] 未检测到火焰或烟雾 (0.04s)
# [Batch 3529] 未检测到火焰或烟雾 (0.04s)
# [Batch 3530] 未检测到火焰或烟雾 (0.04s)
# [Batch 3531] 未检测到火焰或烟雾 (0.04s)
# [Batch 3532] 未检测到火焰或烟雾 (0.04s)
# [Batch 3533] 未检测到火焰或烟雾 (0.04s)
# [Batch 3534] 未检测到火焰或烟雾 (0.04s)
# [Batch 3535] 未检测到火焰或烟雾 (0.04s)
# [Batch 3536] 未检测到火焰或烟雾 (0.04s)
# [Batch 3537] 未检测到火焰或烟雾 (0.04s)
# [Batch 3538] 未检测到火焰或烟雾 (0.04s)
# [Batch 3539] 未检测到火焰或烟雾 (0.04s)
# [Batch 3540] 未检测到火焰或烟雾 (0.04s)
# [Batch 3541] 未检测到火焰或烟雾 (0.04s)
# [Batch 3542] 未检测到火焰或烟雾 (0.04s)
# [Batch 3543] 未检测到火焰或烟雾 (0.04s)
# [Batch 3544] 未检测到火焰或烟雾 (0.04s)
# [Batch 3545] 未检测到火焰或烟雾 (0.04s)
# [Batch 3546] 未检测到火焰或烟雾 (0.04s)
# [Batch 3547] 未检测到火焰或烟雾 (0.04s)
# [Batch 3548] 未检测到火焰或烟雾 (0.04s)
# [Batch 3549] 未检测到火焰或烟雾 (0.04s)
# [Batch 3550] 未检测到火焰或烟雾 (0.04s)
# [Batch 3551] 未检测到火焰或烟雾 (0.04s)
# [Batch 3552] 未检测到火焰或烟雾 (0.04s)
# [Batch 3553] 未检测到火焰或烟雾 (0.04s)
# [Batch 3554] 未检测到火焰或烟雾 (0.04s)
# [Batch 3555] 未检测到火焰或烟雾 (0.04s)
# [Batch 3556] 未检测到火焰或烟雾 (0.04s)
# [Batch 3557] 未检测到火焰或烟雾 (0.04s)
# [Batch 3558] 未检测到火焰或烟雾 (0.04s)
# [Batch 3559] 未检测到火焰或烟雾 (0.04s)
# [Batch 3560] 未检测到火焰或烟雾 (0.04s)
# [Batch 3561] 未检测到火焰或烟雾 (0.04s)
# [Batch 3562] 未检测到火焰或烟雾 (0.04s)
# [Batch 3563] 未检测到火焰或烟雾 (0.04s)
# [Batch 3564] 未检测到火焰或烟雾 (0.04s)
# [Batch 3565] 未检测到火焰或烟雾 (0.04s)
# [Batch 3566] 未检测到火焰或烟雾 (0.04s)
# [Batch 3567] 未检测到火焰或烟雾 (0.04s)
# [Batch 3568] 未检测到火焰或烟雾 (0.04s)
# [Batch 3569] 未检测到火焰或烟雾 (0.04s)
# [Batch 3570] 未检测到火焰或烟雾 (0.04s)
# [Batch 3571] 未检测到火焰或烟雾 (0.04s)
# [Batch 3572] 未检测到火焰或烟雾 (0.04s)
# [Batch 3573] 未检测到火焰或烟雾 (0.04s)
# [Batch 3574] 未检测到火焰或烟雾 (0.04s)
# [Batch 3575] 未检测到火焰或烟雾 (0.04s)
# [Batch 3576] 未检测到火焰或烟雾 (0.04s)
# [Batch 3577] 未检测到火焰或烟雾 (0.04s)
# [Batch 3578] 未检测到火焰或烟雾 (0.04s)
# [Batch 3579] 未检测到火焰或烟雾 (0.04s)
# [Batch 3580] 未检测到火焰或烟雾 (0.04s)
# [Batch 3581] 未检测到火焰或烟雾 (0.04s)
# [Batch 3582] 未检测到火焰或烟雾 (0.04s)
# [Batch 3583] 未检测到火焰或烟雾 (0.04s)
# [Batch 3584] 未检测到火焰或烟雾 (0.04s)
# [Batch 3585] 未检测到火焰或烟雾 (0.04s)
# [Batch 3586] 未检测到火焰或烟雾 (0.04s)
# [Batch 3587] 未检测到火焰或烟雾 (0.04s)
# [Batch 3588] 未检测到火焰或烟雾 (0.04s)
# [Batch 3589] 未检测到火焰或烟雾 (0.04s)
# [Batch 3590] 未检测到火焰或烟雾 (0.04s)
# [Batch 3591] 未检测到火焰或烟雾 (0.04s)
# [Batch 3592] 未检测到火焰或烟雾 (0.04s)
# [Batch 3593] 未检测到火焰或烟雾 (0.04s)
# [Batch 3594] 未检测到火焰或烟雾 (0.04s)
# [Batch 3595] 未检测到火焰或烟雾 (0.04s)
# [Batch 3596] 未检测到火焰或烟雾 (0.04s)
# [Batch 3597] 未检测到火焰或烟雾 (0.04s)
# [Batch 3598] 未检测到火焰或烟雾 (0.04s)
# [Batch 3599] 未检测到火焰或烟雾 (0.04s)
# [Batch 3600] 未检测到火焰或烟雾 (0.04s)
# [Batch 3601] 未检测到火焰或烟雾 (0.04s)
# [Batch 3602] 未检测到火焰或烟雾 (0.04s)
# [Batch 3603] 未检测到火焰或烟雾 (0.04s)
# [Batch 3604] 未检测到火焰或烟雾 (0.04s)
# [Batch 3605] 未检测到火焰或烟雾 (0.04s)
# [Batch 3606] 未检测到火焰或烟雾 (0.04s)
# [Batch 3607] 未检测到火焰或烟雾 (0.04s)
# [Batch 3608] 未检测到火焰或烟雾 (0.04s)
# [Batch 3609] 未检测到火焰或烟雾 (0.04s)
# [Batch 3610] 未检测到火焰或烟雾 (0.04s)
# [Batch 3611] 未检测到火焰或烟雾 (0.04s)
# [Batch 3612] 未检测到火焰或烟雾 (0.04s)
# [Batch 3613] 未检测到火焰或烟雾 (0.04s)
# [Batch 3614] 未检测到火焰或烟雾 (0.04s)
# [Batch 3615] 未检测到火焰或烟雾 (0.04s)
# [Batch 3616] 未检测到火焰或烟雾 (0.04s)
# [Batch 3617] 未检测到火焰或烟雾 (0.04s)
# [Batch 3618] 未检测到火焰或烟雾 (0.04s)
# [Batch 3619] 未检测到火焰或烟雾 (0.04s)
# [Batch 3620] 未检测到火焰或烟雾 (0.04s)
# [Batch 3621] 未检测到火焰或烟雾 (0.04s)
# [Batch 3622] 未检测到火焰或烟雾 (0.04s)
# [Batch 3623] 未检测到火焰或烟雾 (0.04s)
# [Batch 3624] 未检测到火焰或烟雾 (0.04s)
# [Batch 3625] 未检测到火焰或烟雾 (0.04s)
# [Batch 3626] 未检测到火焰或烟雾 (0.04s)
# [Batch 3627] 未检测到火焰或烟雾 (0.04s)
# [Batch 3628] 未检测到火焰或烟雾 (0.04s)
# [Batch 3629] 未检测到火焰或烟雾 (0.04s)
# [Batch 3630] 未检测到火焰或烟雾 (0.04s)
# [Batch 3631] 未检测到火焰或烟雾 (0.04s)
# [Batch 3632] 未检测到火焰或烟雾 (0.04s)
# [Batch 3633] 未检测到火焰或烟雾 (0.04s)
# [Batch 3634] 未检测到火焰或烟雾 (0.04s)
# [Batch 3635] 未检测到火焰或烟雾 (0.04s)
# [Batch 3636] 未检测到火焰或烟雾 (0.04s)
# [Batch 3637] 未检测到火焰或烟雾 (0.04s)
# [Batch 3638] 未检测到火焰或烟雾 (0.04s)
# [Batch 3639] 未检测到火焰或烟雾 (0.04s)
# [Batch 3640] 未检测到火焰或烟雾 (0.04s)
# [Batch 3641] 未检测到火焰或烟雾 (0.04s)
# [Batch 3642] 未检测到火焰或烟雾 (0.04s)
# [Batch 3643] 未检测到火焰或烟雾 (0.04s)
# [Batch 3644] 未检测到火焰或烟雾 (0.04s)
# [Batch 3645] 未检测到火焰或烟雾 (0.04s)
# [Batch 3646] 未检测到火焰或烟雾 (0.04s)
# [Batch 3647] 未检测到火焰或烟雾 (0.04s)
# [Batch 3648] 未检测到火焰或烟雾 (0.04s)
# [Batch 3649] 未检测到火焰或烟雾 (0.04s)
# [Batch 3650] 未检测到火焰或烟雾 (0.04s)
# [Batch 3651] 未检测到火焰或烟雾 (0.04s)
# [Batch 3652] 未检测到火焰或烟雾 (0.04s)
# [Batch 3653] 未检测到火焰或烟雾 (0.04s)
# [Batch 3654] 未检测到火焰或烟雾 (0.04s)
# [Batch 3655] 未检测到火焰或烟雾 (0.04s)
# [Batch 3656] 未检测到火焰或烟雾 (0.04s)
# [Batch 3657] 未检测到火焰或烟雾 (0.04s)
# [Batch 3658] 未检测到火焰或烟雾 (0.04s)
# [Batch 3659] 未检测到火焰或烟雾 (0.04s)
# [Batch 3660] 未检测到火焰或烟雾 (0.04s)
# [Batch 3661] 未检测到火焰或烟雾 (0.04s)
# [Batch 3662] 未检测到火焰或烟雾 (0.04s)
# [Batch 3663] 未检测到火焰或烟雾 (0.04s)
# [Batch 3664] 未检测到火焰或烟雾 (0.04s)
# [Batch 3665] 未检测到火焰或烟雾 (0.04s)
# [Batch 3666] 未检测到火焰或烟雾 (0.04s)
# [Batch 3667] 未检测到火焰或烟雾 (0.04s)
# [Batch 3668] 未检测到火焰或烟雾 (0.04s)
# [Batch 3669] 未检测到火焰或烟雾 (0.04s)
# [Batch 3670] 未检测到火焰或烟雾 (0.04s)
# [Batch 3671] 未检测到火焰或烟雾 (0.04s)
# [Batch 3672] 未检测到火焰或烟雾 (0.04s)
# [Batch 3673] 未检测到火焰或烟雾 (0.04s)
# [Batch 3674] 未检测到火焰或烟雾 (0.04s)
# [Batch 3675] 未检测到火焰或烟雾 (0.04s)
# [Batch 3676] 未检测到火焰或烟雾 (0.04s)
# [Batch 3677] 未检测到火焰或烟雾 (0.04s)
# [Batch 3678] 未检测到火焰或烟雾 (0.04s)
# [Batch 3679] 未检测到火焰或烟雾 (0.04s)
# [Batch 3680] 未检测到火焰或烟雾 (0.04s)
# [Batch 3681] 未检测到火焰或烟雾 (0.04s)
# [Batch 3682] 未检测到火焰或烟雾 (0.04s)
# [Batch 3683] 未检测到火焰或烟雾 (0.04s)
# [Batch 3684] 未检测到火焰或烟雾 (0.04s)
# [Batch 3685] 未检测到火焰或烟雾 (0.04s)
# [Batch 3686] 未检测到火焰或烟雾 (0.04s)
# [Batch 3687] 未检测到火焰或烟雾 (0.04s)
# [Batch 3688] 未检测到火焰或烟雾 (0.04s)
# [Batch 3689] 未检测到火焰或烟雾 (0.04s)
# [Batch 3690] 未检测到火焰或烟雾 (0.04s)
# [Batch 3691] 未检测到火焰或烟雾 (0.04s)
# [Batch 3692] 未检测到火焰或烟雾 (0.04s)
# [Batch 3693] 未检测到火焰或烟雾 (0.04s)
# [Batch 3694] 未检测到火焰或烟雾 (0.04s)
# [Batch 3695] 未检测到火焰或烟雾 (0.04s)
# [Batch 3696] 未检测到火焰或烟雾 (0.04s)
# [Batch 3697] 未检测到火焰或烟雾 (0.04s)
# [Batch 3698] 未检测到火焰或烟雾 (0.04s)
# [Batch 3699] 未检测到火焰或烟雾 (0.04s)
# [Batch 3700] 未检测到火焰或烟雾 (0.04s)
# [Batch 3701] 未检测到火焰或烟雾 (0.04s)
# [Batch 3702] 未检测到火焰或烟雾 (0.04s)
# [Batch 3703] 未检测到火焰或烟雾 (0.04s)
# [Batch 3704] 未检测到火焰或烟雾 (0.04s)
# [Batch 3705] 未检测到火焰或烟雾 (0.04s)
# [Batch 3706] 未检测到火焰或烟雾 (0.04s)
# [Batch 3707] 未检测到火焰或烟雾 (0.04s)
# [Batch 3708] 未检测到火焰或烟雾 (0.04s)
# [Batch 3709] 未检测到火焰或烟雾 (0.04s)
# [Batch 3710] 未检测到火焰或烟雾 (0.04s)
# [Batch 3711] 未检测到火焰或烟雾 (0.04s)
# [Batch 3712] 未检测到火焰或烟雾 (0.04s)
# [Batch 3713] 未检测到火焰或烟雾 (0.04s)
# [Batch 3714] 未检测到火焰或烟雾 (0.04s)
# [Batch 3715] 未检测到火焰或烟雾 (0.04s)
# [Batch 3716] 未检测到火焰或烟雾 (0.04s)
# [Batch 3717] 未检测到火焰或烟雾 (0.04s)
# [Batch 3718] 未检测到火焰或烟雾 (0.04s)
# [Batch 3719] 未检测到火焰或烟雾 (0.04s)
# [Batch 3720] 未检测到火焰或烟雾 (0.04s)
# [Batch 3721] 未检测到火焰或烟雾 (0.04s)
# [Batch 3722] 未检测到火焰或烟雾 (0.04s)
# [Batch 3723] 未检测到火焰或烟雾 (0.04s)
# [Batch 3724] 未检测到火焰或烟雾 (0.04s)
# [Batch 3725] 未检测到火焰或烟雾 (0.04s)
# [Batch 3726] 未检测到火焰或烟雾 (0.04s)
# [Batch 3727] 未检测到火焰或烟雾 (0.04s)
# [Batch 3728] 未检测到火焰或烟雾 (0.04s)
# [Batch 3729] 未检测到火焰或烟雾 (0.04s)
# [Batch 3730] 未检测到火焰或烟雾 (0.04s)
# [Batch 3731] 未检测到火焰或烟雾 (0.04s)
# [Batch 3732] 未检测到火焰或烟雾 (0.04s)
# [Batch 3733] 未检测到火焰或烟雾 (0.04s)
# [Batch 3734] 未检测到火焰或烟雾 (0.04s)
# [Batch 3735] 未检测到火焰或烟雾 (0.04s)
# [Batch 3736] 未检测到火焰或烟雾 (0.04s)
# [Batch 3737] 未检测到火焰或烟雾 (0.04s)
# [Batch 3738] 未检测到火焰或烟雾 (0.04s)
# [Batch 3739] 未检测到火焰或烟雾 (0.04s)
# [Batch 3740] 未检测到火焰或烟雾 (0.04s)
# [Batch 3741] 未检测到火焰或烟雾 (0.04s)
# [Batch 3742] 未检测到火焰或烟雾 (0.04s)
# [Batch 3743] 未检测到火焰或烟雾 (0.04s)
# [Batch 3744] 未检测到火焰或烟雾 (0.04s)
# [Batch 3745] 未检测到火焰或烟雾 (0.04s)
# [Batch 3746] 未检测到火焰或烟雾 (0.04s)
# [Batch 3747] 未检测到火焰或烟雾 (0.04s)
# [Batch 3748] 未检测到火焰或烟雾 (0.04s)
# [Batch 3749] 未检测到火焰或烟雾 (0.04s)
# [Batch 3750] 未检测到火焰或烟雾 (0.04s)
# [Batch 3751] 未检测到火焰或烟雾 (0.04s)
# [Batch 3752] 未检测到火焰或烟雾 (0.04s)
# [Batch 3753] 未检测到火焰或烟雾 (0.04s)
# [Batch 3754] 未检测到火焰或烟雾 (0.04s)
# [Batch 3755] 未检测到火焰或烟雾 (0.04s)
# [Batch 3756] 未检测到火焰或烟雾 (0.04s)
# [Batch 3757] 未检测到火焰或烟雾 (0.04s)
# [Batch 3758] 未检测到火焰或烟雾 (0.04s)
# [Batch 3759] 未检测到火焰或烟雾 (0.04s)
# [Batch 3760] 未检测到火焰或烟雾 (0.04s)
# [Batch 3761] 未检测到火焰或烟雾 (0.04s)
# [Batch 3762] 未检测到火焰或烟雾 (0.04s)
# [Batch 3763] 未检测到火焰或烟雾 (0.04s)
# [Batch 3764] 未检测到火焰或烟雾 (0.04s)
# [Batch 3765] 未检测到火焰或烟雾 (0.04s)
# [Batch 3766] 未检测到火焰或烟雾 (0.04s)
# [Batch 3767] 未检测到火焰或烟雾 (0.04s)
# [Batch 3768] 未检测到火焰或烟雾 (0.04s)
# [Batch 3769] 未检测到火焰或烟雾 (0.04s)
# [Batch 3770] 未检测到火焰或烟雾 (0.04s)
# [Batch 3771] 未检测到火焰或烟雾 (0.04s)
# [Batch 3772] 未检测到火焰或烟雾 (0.04s)
# [Batch 3773] 未检测到火焰或烟雾 (0.04s)
# [Batch 3774] 未检测到火焰或烟雾 (0.04s)
# [Batch 3775] 未检测到火焰或烟雾 (0.04s)
# [Batch 3776] 未检测到火焰或烟雾 (0.04s)
# [Batch 3777] 未检测到火焰或烟雾 (0.04s)
# [Batch 3778] 未检测到火焰或烟雾 (0.04s)
# [Batch 3779] 未检测到火焰或烟雾 (0.04s)
# [Batch 3780] 未检测到火焰或烟雾 (0.04s)
# [Batch 3781] 未检测到火焰或烟雾 (0.04s)
# [Batch 3782] 未检测到火焰或烟雾 (0.04s)
# [Batch 3783] 未检测到火焰或烟雾 (0.04s)
# [Batch 3784] 未检测到火焰或烟雾 (0.04s)
# [Batch 3785] 未检测到火焰或烟雾 (0.04s)
# [Batch 3786] 未检测到火焰或烟雾 (0.04s)
# [Batch 3787] 未检测到火焰或烟雾 (0.04s)
# [Batch 3788] 未检测到火焰或烟雾 (0.04s)
# [Batch 3789] 未检测到火焰或烟雾 (0.04s)
# [Batch 3790] 未检测到火焰或烟雾 (0.04s)
# [Batch 3791] 未检测到火焰或烟雾 (0.04s)
# [Batch 3792] 未检测到火焰或烟雾 (0.04s)
# [Batch 3793] 未检测到火焰或烟雾 (0.04s)
# [Batch 3794] 未检测到火焰或烟雾 (0.04s)
# [Batch 3795] 未检测到火焰或烟雾 (0.04s)
# [Batch 3796] 未检测到火焰或烟雾 (0.04s)
# [Batch 3797] 未检测到火焰或烟雾 (0.04s)
# [Batch 3798] 未检测到火焰或烟雾 (0.04s)
# [Batch 3799] 未检测到火焰或烟雾 (0.04s)
# [Batch 3800] 未检测到火焰或烟雾 (0.04s)
# [Batch 3801] 未检测到火焰或烟雾 (0.04s)
# [Batch 3802] 未检测到火焰或烟雾 (0.04s)
# [Batch 3803] 未检测到火焰或烟雾 (0.04s)
# [Batch 3804] 未检测到火焰或烟雾 (0.04s)
# [Batch 3805] 未检测到火焰或烟雾 (0.04s)
# [Batch 3806] 未检测到火焰或烟雾 (0.04s)
# [Batch 3807] 未检测到火焰或烟雾 (0.04s)
# [Batch 3808] 未检测到火焰或烟雾 (0.04s)
# [Batch 3809] 未检测到火焰或烟雾 (0.04s)
# [Batch 3810] 未检测到火焰或烟雾 (0.04s)
# [Batch 3811] 未检测到火焰或烟雾 (0.04s)
# [Batch 3812] 未检测到火焰或烟雾 (0.04s)
# [Batch 3813] 未检测到火焰或烟雾 (0.04s)
# [Batch 3814] 未检测到火焰或烟雾 (0.04s)
# [Batch 3815] 未检测到火焰或烟雾 (0.04s)
# [Batch 3816] 未检测到火焰或烟雾 (0.04s)
# [Batch 3817] 未检测到火焰或烟雾 (0.04s)
# [Batch 3818] 未检测到火焰或烟雾 (0.04s)
# [Batch 3819] 未检测到火焰或烟雾 (0.04s)
# [Batch 3820] 未检测到火焰或烟雾 (0.04s)
# [Batch 3821] 未检测到火焰或烟雾 (0.04s)
# [Batch 3822] 未检测到火焰或烟雾 (0.04s)
# [Batch 3823] 未检测到火焰或烟雾 (0.04s)
# [Batch 3824] 未检测到火焰或烟雾 (0.04s)
# [Batch 3825] 未检测到火焰或烟雾 (0.04s)
# [Batch 3826] 未检测到火焰或烟雾 (0.04s)
# [Batch 3827] 未检测到火焰或烟雾 (0.04s)
# [Batch 3828] 未检测到火焰或烟雾 (0.04s)
# [Batch 3829] 未检测到火焰或烟雾 (0.04s)
# [Batch 3830] 未检测到火焰或烟雾 (0.04s)
# [Batch 3831] 未检测到火焰或烟雾 (0.04s)
# [Batch 3832] 未检测到火焰或烟雾 (0.04s)
# [Batch 3833] 未检测到火焰或烟雾 (0.04s)
# [Batch 3834] 未检测到火焰或烟雾 (0.04s)
# [Batch 3835] 未检测到火焰或烟雾 (0.04s)
# [Batch 3836] 未检测到火焰或烟雾 (0.04s)
# [Batch 3837] 未检测到火焰或烟雾 (0.04s)
# [Batch 3838] 帧数不足: 3 < 10 (0.00s)
#
# 视频已保存: output.mp4
# 预览图片已保存: 1324 张 -> /home/cxt/projects/fpa_fire_detection/preview_frames
#
# ==================================================
# 检测统计
# ==================================================
#   处理批次: 3838
#   火灾检出: 1523 次
#   静态疑似: 481 次
#   无检测: 1834 次
# ==================================================
#
# 检测完成!
